# %% [markdown]
# # County Permits

# %%
import os
import io
import requests
import time
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import seaborn as sns
sns.set_style(style='darkgrid')
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point, Polygon
import re
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)
# %matplotlib inline

# %% [markdown]
# ## Overview

# %%
#cp = pd.read_csv('https://data.montgomerycountymd.gov/resource/i26v-w6bd.csv')
cp = pd.read_csv('Commercial_Permits (4).csv')
#The new updated link still only loads up a thousand rows

# %%
cp.tail()
# Out:
#        Permit Number   Status Street Number Pre-direction      Street Name  \
# 28801         744532  Finaled          9704           NaN   MEDICAL CENTER
# 28802         745364  Finaled          4800           NaN          HAMPDEN
# 28803         745969  Finaled          4806           NaN       MONTGOMERY
# 28804         744012     Open         12510           NaN  PENNYFIELD LOCK
# 28805         744731   Issued          2219           NaN          BEL PRE
#
#       Street Suffix Post-direction           City State  ZIP code  Added Date  \
# 28801            DR            NaN      ROCKVILLE    MD   20850.0  02/12/2016
# 28802            LN            NaN       BETHESDA    MD   20814.0  02/22/2016
# 28803            LN            NaN       BETHESDA    MD   20814.0  02/25/2016
# 28804            RD            NaN        POTOMAC    MD   20854.0  02/08/2016
# 28805            RD            NaN  SILVER SPRING    MD   20906.0  02/16/2016
#
#        Issue Date  Final Date  Building Area  Declared Valuation  \
# 28801  03/14/2016  03/21/2017        27000.0           1162792.0
# 28802  04/29/2016  08/18/2016        11027.0            527683.0
# 28803  03/04/2016  05/24/2016          700.0              8000.0
# 28804         NaN         NaN            1.0             50825.0
# 28805  07/01/2016         NaN        36363.0           4300000.0
#
#                                              Description     Application Type  \
# 28801  Interior Alterations : including systems Furni...  COMMERCIAL BUILDING
# 28802  Partial renovation of the 3rd Floor Revision 0...  COMMERCIAL BUILDING
# 28803                   Restore and repair -Girder Truss  COMMERCIAL BUILDING
# 28804       2 TIERED 18 FT RETAINING WALL IN COMMON AREA  COMMERCIAL BUILDING
# 28805  Customer Wants To Use ePlans,Construction of a...  COMMERCIAL BUILDING
#
#                      Work Type                        Use Code  \
# 28801                    ALTER               BUSINESS BUILDING
# 28802                    ALTER               BUSINESS BUILDING
# 28803  RESTORE AND / OR REPAIR                       TOWNHOUSE
# 28804                CONSTRUCT                  RETAINING WALL
# 28805                CONSTRUCT  COMMERCIAL MISCELLANEOUS STRUC
#
#                                                 Location
# 28801  9704 MEDICAL CENTER DR\nROCKVILLE, MD 20850\n(...
# 28802  4800 HAMPDEN LN\nBETHESDA, MD 20814\n(38.98271...
# 28803  4806 MONTGOMERY LN\nBETHESDA, MD 20814\n(38.98...
# 28804  12510 PENNYFIELD LOCK RD\nPOTOMAC, MD 20854\n(...
# 28805  2219 BEL PRE RD\nSILVER SPRING, MD 20906\n(39....

# %%
cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28806 entries, 0 to 28805
# Data columns (total 20 columns):
# Permit Number         28806 non-null int64
# Status                28806 non-null object
# Street Number         27655 non-null object
# Pre-direction         749 non-null object
# Street Name           27677 non-null object
# Street Suffix         27626 non-null object
# Post-direction        63 non-null object
# City                  27657 non-null object
# State                 27652 non-null object
# ZIP code              27611 non-null float64
# Added Date            28806 non-null object
# Issue Date            27072 non-null object
# Final Date            15691 non-null object
# Building Area         27133 non-null float64
# Declared Valuation    27946 non-null float64
# Description           26652 non-null object
# Application Type      28806 non-null object
# Work Type             28802 non-null object
# Use Code              28806 non-null object
# Location              27677 non-null object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 4.4+ MB

# %%
cp.describe().T
# Out:
#                       count           mean           std       min       25%  \
# Permit Number       28806.0  606784.408387  5.887310e+06  208677.0  405144.0
# ZIP code            27611.0   20862.615588  2.360910e+02       0.0   20841.0
# Building Area       27133.0   10601.539407  4.358353e+04       0.0     350.0
# Declared Valuation  27946.0  757027.594376  8.160478e+06       0.0   18000.0
#
#                          50%        75%           max
# Permit Number       575960.5  747323.25  9.992111e+08
# ZIP code             20871.0   20902.00  2.177100e+04
# Building Area         1636.0    4320.00  1.600000e+06
# Declared Valuation   60000.0  200000.00  1.129634e+09

# %%
cp.head()
# Out:
#    Permit Number   Status Street Number Pre-direction   Street Name  \
# 0         891330     Open          5471           NaN     WISCONSIN
# 1         891377     Open           312           NaN     BALTUSROL
# 2         788131   Issued         12100           NaN  PLUM ORCHARD
# 3         873775   Issued         18320           NaN       CONTOUR
# 4         863967  Finaled         11545           NaN     ROCKVILLE
#
#   Street Suffix Post-direction                City State  ZIP code  \
# 0           AVE            NaN         CHEVY CHASE    MD   20815.0
# 1            DR            NaN          GERMANTOWN    MD   20874.0
# 2            DR            NaN       SILVER SPRING    MD   20904.0
# 3            RD            NaN  MONTGOMERY VILLAGE    MD   20886.0
# 4          PIKE            NaN           ROCKVILLE    MD   20852.0
#
#    Added Date  Issue Date  Final Date  Building Area  Declared Valuation  \
# 0  09/30/2019         NaN         NaN          100.0             30000.0
# 1  09/30/2019         NaN         NaN          300.0             25000.0
# 2  01/31/2017  04/11/2017         NaN       294813.0          73000000.0
# 3  04/29/2019  06/28/2019         NaN          920.0             79000.0
# 4  01/21/2019  05/31/2019  08/16/2019        30960.0           1937700.0
#
#                                          Description     Application Type  \
# 0               RESTORE &amp; REPAIR STRUCTURAL BEAM  COMMERCIAL BUILDING
# 1  Customer Wants To Use ePlans,brick on CMU wall...  COMMERCIAL BUILDING
# 2  Revision 3 - Vertical expansion const. on the ...  COMMERCIAL BUILDING
# 3              CHANGE OF USE: Business to RESTAURANT  COMMERCIAL BUILDING
# 4  Revision ,01 - Modify construction details.  N...  COMMERCIAL BUILDING
#
#                   Work Type                        Use Code  \
# 0   RESTORE AND / OR REPAIR               BUSINESS BUILDING
# 1                 CONSTRUCT  COMMERCIAL MISCELLANEOUS STRUC
# 2                 CONSTRUCT                        HOSPITAL
# 3  COMMERCIAL CHANGE OF USE                      RESTAURANT
# 4                     ALTER               BUSINESS BUILDING
#
#                                             Location
# 0  5471 WISCONSIN AVE\nCHEVY CHASE, MD 20815\n(38...
# 1             312 BALTUSROL DR\nGERMANTOWN, MD 20874
# 2  12100 PLUM ORCHARD DR\nSILVER SPRING, MD 20904...
# 3  18320 CONTOUR RD\nMONTGOMERY VILLAGE, MD 20886...
# 4  11545 ROCKVILLE PIKE\nROCKVILLE, MD 20852\n(39...

# %%
cp['Permit Number'].nunique()
# Out:
# 28806

# %% [markdown]
# # Wrangling

# %%
cpr = cp.rename({"Permit Number":"P_num", "Street Number":"St_number", "Pre-direction": "Pre_d", "Street Name":"St_name", "Street Number":"St_num",
                 "Street Suffix":"St_suf", "Post-direction":"Post_d","ZIP code":"Zip", "Added Date":"A_date",
                 "Issue Date":"I_date","Final Date":"F_date", "Building Area":"Building_area", "Building Area":"Building_area", 
                 "Declared Valuation":"Decl_v", "Description":"Desc", "Application Type":"A_type", "Work Type":"W_type", "Use Code":"U_code"}, axis='columns')

# %%
#sorting Values by "P_num"
cp1 = cpr.sort_values(["P_num"])
#change index to match P_num
cp2 = cp1.reset_index(drop=True)
cp2.shape
# Out:
# (28806, 20)

# %%
#Droping Application type and state since all are commerical in this set
cp1[(cp1['A_type'] != 'COMMERCIAL BUILDING')]
cp2.drop('A_type', axis=1, inplace=True)
cp2.drop('State', axis=1, inplace=True)

# %%
#Changing dates to DateTime
cp2.A_date = pd.to_datetime(cp2.A_date)
cp2.I_date = pd.to_datetime(cp2.I_date)
cp2.F_date = pd.to_datetime(cp2.F_date)
type(cp2.F_date[1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#changeing Zip from a float to a string
cp2.Zip = cp2.Zip.fillna(-1)
cp2.Zip = cp2.Zip.astype(int)
cp2.Zip = cp2.Zip.astype(str)
cp2.Zip = cp2.Zip.replace('-1', "Na")
type(cp2.Zip[1])
#what was wrong with this
# Out:
# str

# %%
cp2.head()
# Out:
#     P_num   Status St_num Pre_d   St_name St_suf Post_d        City    Zip  \
# 0  208677  Finaled  19850   NaN   CENTURY   BLVD    NaN  GERMANTOWN  20874
# 1  208678  Finaled  12901   NaN  PINNACLE     DR    NaN  GERMANTOWN  20874
# 2  208679  Finaled  12903   NaN  PINNACLE     DR    NaN  GERMANTOWN  20874
# 3  208689  Finaled  12907   NaN  PINNACLE     DR    NaN  GERMANTOWN  20874
# 4  208690  Finaled  12909   NaN  PINNACLE     DR    NaN  GERMANTOWN  20874
#
#       A_date     I_date     F_date  Building_area     Decl_v Desc     W_type  \
# 0 2000-01-03 2000-12-14 2001-10-10        42600.0  1000000.0  NaN  CONSTRUCT
# 1 2000-01-03 2000-12-14 2001-10-11        42600.0  1000000.0  NaN  CONSTRUCT
# 2 2000-01-03 2000-12-14 2001-10-12        42600.0  1000000.0  NaN  CONSTRUCT
# 3 2000-01-03 2000-12-14 2002-01-31        63300.0  1500000.0  NaN  CONSTRUCT
# 4 2000-01-03 2000-12-14 2002-01-29        63300.0  1500000.0  NaN  CONSTRUCT
#
#                   U_code                                           Location
# 0  MULTI-FAMILY DWELLING  19850 CENTURY BLVD\nGERMANTOWN, MD 20874\n(39....
# 1  MULTI-FAMILY DWELLING  12901 PINNACLE DR\nGERMANTOWN, MD 20874\n(39.1...
# 2  MULTI-FAMILY DWELLING  12903 PINNACLE DR\nGERMANTOWN, MD 20874\n(39.1...
# 3  MULTI-FAMILY DWELLING  12907 PINNACLE DR\nGERMANTOWN, MD 20874\n(39.1...
# 4  MULTI-FAMILY DWELLING  12909 PINNACLE DR\nGERMANTOWN, MD 20874\n(39.1...

# %%
cp2.shape
# Out:
# (28806, 18)

# %% [markdown]
# Dealing with missing Data

# %%
cp2.isnull().values.sum()
# Out:
# 82078

# %%
#Calculating the percentage of missing data
missing_data = cp2.isnull().sum()
missing_data / len(cp2) * 100
#find out based on year
# Out:
# P_num             0.000000
# Status            0.000000
# St_num            3.995695
# Pre_d            97.399847
# St_name           3.919322
# St_suf            4.096369
# Post_d           99.781296
# City              3.988752
# Zip               0.000000
# A_date            0.000000
# I_date            6.019579
# F_date           45.528709
# Building_area     5.807818
# Decl_v            2.985489
# Desc              7.477609
# W_type            0.013886
# U_code            0.000000
# Location          3.919322
# dtype: float64

# %%
#Filling in Na's for post and pre directions
cp3 = cp2.copy()
cp2.loc[cp2.Post_d.notnull()]
cp3.Post_d.fillna("N/A", inplace=True)
cp2.loc[cp2.Pre_d.notnull()]
cp3.Pre_d.fillna("N/A",inplace =True)

# %%
cp1.Desc.isna().sum()
# Out:
# 2154

# %%
cp3.Desc.fillna("N/A",inplace =True)

# %%
cp3.isnull().values.sum()
# Out:
# 23124

# %% [markdown]
# Dealing with Finaled date
# Seeing that the status and finalled are the same

# %%
cp3.F_date.notnull().sum()
# Out:
# 15691

# %%
cp3.Status.value_counts()
# Out:
# Finaled      15600
# Issued       10712
# Open          1667
# Stop Work      827
# Name: Status, dtype: int64

# %% [markdown]
# Here I am checking that the Status column and the Issue and Added Dates match.

# %%
#Decrepancey of 91
cp3.loc[(cp3.Status == 'Stop Work' ) & cp3.F_date.notnull()]
# contains 84 non-null, so still need 7
cp3.loc[(cp3.Status == 'Issued' ) & cp3.F_date.notnull()]
# there we go so 7 which in total accounts for the decrpeancy of 91
cp3.loc[(cp3.Status == 'Open' ) & cp3.F_date.notnull()]
#all are null
# Out:
# Empty DataFrame
# Columns: [P_num, Status, St_num, Pre_d, St_name, St_suf, Post_d, City, Zip, A_date, I_date, F_date, Building_area, Decl_v, Desc, W_type, U_code, Location]
# Index: []

# %%
cp3.F_date.fillna("N/A",inplace =True)

# %%
missing_data3 = cp3.isnull().sum()
missing_data3
# Out:
# P_num               0
# Status              0
# St_num           1151
# Pre_d               0
# St_name          1129
# St_suf           1180
# Post_d              0
# City             1149
# Zip                 0
# A_date              0
# I_date           1734
# F_date              0
# Building_area    1673
# Decl_v            860
# Desc                0
# W_type              4
# U_code              0
# Location         1129
# dtype: int64

# %% [markdown]
# So before I deal with the rest of the NA's I am going to drop all the faulty location data

# %%
Naloc = cp3[cp3.Location.isnull() & cp3.St_num.isnull() & 
            cp3.City.isnull() &  cp3.Zip.isnull()]
Naloc.describe()
# Out:
#        P_num  Building_area  Decl_v
# count    0.0            0.0     0.0
# mean     NaN            NaN     NaN
# std      NaN            NaN     NaN
# min      NaN            NaN     NaN
# 25%      NaN            NaN     NaN
# 50%      NaN            NaN     NaN
# 75%      NaN            NaN     NaN
# max      NaN            NaN     NaN

# %%
D2 = cp3.copy()
D2.dropna(subset=[ 'Location', 'Zip', 'City', 'St_num', 'St_name' ], inplace=True)
D2.shape
# Out:
# (27636, 18)

# %%
missing_data4 = D2.isnull().sum()
missing_data4
# Out:
# P_num               0
# Status              0
# St_num              0
# Pre_d               0
# St_name             0
# St_suf             48
# Post_d              0
# City                0
# Zip                 0
# A_date              0
# I_date           1532
# F_date              0
# Building_area    1603
# Decl_v            822
# Desc                0
# W_type              3
# U_code              0
# Location            0
# dtype: int64

# %% [markdown]
# Dealing with the remaining Values

# %%
#Declared Value
D2.Decl_v.value_counts
D2.Decl_v = D2.Decl_v.fillna(0)

# %%
D2.Building_area.value_counts()
D2.Building_area = D2.Building_area.fillna(0)

# %%
# manage with editing
D2.loc[(D2.St_suf.isnull())]
# Out:
#         P_num   Status St_num Pre_d           St_name St_suf Post_d  \
# 8480   446385     Open   7500   N/A          WOODMONT    NaN    N/A
# 9825   479721  Finaled  12500   N/A      PARK POTOMAC    NaN    N/A
# 10775  503908   Issued  12500   N/A      PARK POTOMAC    NaN    N/A
# 11445  518289   Issued  12500   N/A      PARK POTOMAC    NaN    N/A
# 11626  522605   Issued  21040   N/A  HENDERSON CORNER    NaN    N/A
# 12038  529231  Finaled  14201   N/A       GEORGIA AVE    NaN    N/A
# 12389  536136  Finaled  14201   N/A       GEORGIA AVE    NaN    N/A
# 12394  536331   Issued  21040   N/A  HENDERSON CORNER    NaN    N/A
# 12476  537804  Finaled   7500   N/A          WOODMONT    NaN    N/A
# 12971  549782   Issued  21040   N/A  HENDERSON CORNER    NaN    N/A
# ...       ...      ...    ...   ...               ...    ...    ...
# 22631  774194  Finaled   7101   N/A         DEMOCRACY    NaN    N/A
# 22695  775797  Finaled   7101   N/A         DEMOCRACY    NaN    N/A
# 23357  792478   Issued   7101   N/A         DEMOCRACY    NaN    N/A
# 23898  803917   Issued   6420   N/A         ROCKLEDGE    NaN    N/A
# 24294  812305   Issued   7500   N/A          WOODMONT    NaN    N/A
# 26795  859886   Issued  12500   N/A      PARK POTOMAC    NaN    N/A
# 26796  859887   Issued  12500   N/A      PARK POTOMAC    NaN    N/A
# 27771  875323   Issued  12500   N/A      PARK POTOMAC    NaN    N/A
# 28405  887292   Issued   6011   N/A         EXECUTIVE    NaN    N/A
# 28622  891305     Open  11160   N/A        VEIRS MILL    NaN    N/A
#
#                 City    Zip     A_date     I_date               F_date  \
# 8480        BETHESDA  20814 2007-03-01        NaT                  N/A
# 9825         POTOMAC  20854 2008-03-11 2008-09-19  2009-05-13 00:00:00
# 10775        POTOMAC  20854 2009-01-22 2009-03-09                  N/A
# 11445        POTOMAC  20854 2009-08-06 2009-08-20                  N/A
# 11626     GERMANTOWN  20876 2009-10-02 2010-08-09                  N/A
# 12038  SILVER SPRING  20906 2010-01-13 2010-04-26  2010-07-19 00:00:00
# 12389  SILVER SPRING  20906 2010-04-26 2010-05-20  2010-12-02 00:00:00
# 12394     GERMANTOWN  20876 2010-04-27 2010-08-03                  N/A
# 12476       BETHESDA  20814 2010-05-13 2010-06-02  2010-06-18 00:00:00
# 12971     GERMANTOWN  20876 2010-09-22 2010-10-05                  N/A
# ...              ...    ...        ...        ...                  ...
# 22631       BETHESDA  20817 2016-09-27 2017-03-13  2018-03-23 00:00:00
# 22695       BETHESDA  20817 2016-10-10 2017-03-13  2018-03-23 00:00:00
# 23357       BETHESDA  20817 2017-03-13 2017-04-19                  N/A
# 23898       BETHESDA  20817 2017-06-21 2017-08-31                  N/A
# 24294       BETHESDA  20814 2017-09-06 2017-11-20                  N/A
# 26795        POTOMAC  20854 2018-12-03 2019-01-22                  N/A
# 26796        POTOMAC  20854 2018-12-03 2019-02-01                  N/A
# 27771        POTOMAC  20854 2019-05-13 2019-07-18                  N/A
# 28405      ROCKVILLE  20854 2019-08-22 2019-10-16                  N/A
# 28622        WHEATON  20902 2019-09-30        NaT                  N/A
#
#        Building_area    Decl_v  \
# 8480             0.0       0.0
# 9825           480.0  200000.0
# 10775          480.0   15000.0
# 11445           40.0    1800.0
# 11626         6622.0  750000.0
# 12038         3500.0   15000.0
# 12389        12305.0  150000.0
# 12394           50.0    3000.0
# 12476           81.0       0.0
# 12971         2000.0   26000.0
# ...              ...       ...
# 22631          500.0   35000.0
# 22695          500.0       1.0
# 23357          927.0   40000.0
# 23898         1719.0  168000.0
# 24294        45000.0  214705.0
# 26795        71200.0  547182.0
# 26796          850.0   88781.0
# 27771            0.0   65000.0
# 28405         2000.0  250000.0
# 28622            1.0   11912.0
#
#                                                     Desc  \
# 8480   Code Modification Only  IBC: Remove the dividi...
# 9825           Entrance to Condos and Canopy Replacement
# 10775  To provide conduit and electrical panels for 3...
# 11445  Unit #907 N\nCoversion of existing bedroom and...
# 11626  Construct new 7-Eleven convenience store with ...
# 12038  FIRE REPAIR BACK TO ORIGINAL CONDITION ONLY - ...
# 12389  FIRE REPAIR BACK TO ORIGINAL CONDITION ONLY - ...
# 12394                                      monument sign
# 12476                      removing fireplace in 3 units
# 12971  Construct Retaining Wall\n**Intermediate Track...
# ...                                                  ...
# 22631  &nbsp;STRUCTURAL REPAIRS&nbsp;FOR &nbsp;MOVIE ...
# 22695  &nbsp;STRUCTURAL REPAIRS FOR THE NORDSTROM&nbs...
# 23357  Customer Wants To Use ePlans,Front counter and...
# 23898  *AO APPLICATION*\n\n&nbsp;Interior work only,M...
# 24294  *AO APPLICATION* Concrete repairs to existing ...
# 26795                Restore &amp; Repair PARKING GARAGE
# 26796  Restore &amp; Repair&nbsp;&nbsp;GARAGE ENTRANC...
# 27771  FACADE REPAIRS TO NORTH &amp; SOUTH TOWERS (BO...
# 28405                            EXTERIOR COLUMN REPAIRS
# 28622  Customer Wants To Use ePlans,Install 1 Solar P...
#
#                         W_type                          U_code  \
# 8480                     ALTER           MULTI-FAMILY DWELLING
# 9825                       ADD           MULTI-FAMILY DWELLING
# 10775                    ALTER             MERCANTILE BUILDING
# 11445                    ALTER           MULTI-FAMILY DWELLING
# 11626                CONSTRUCT             MERCANTILE BUILDING
# 12038  RESTORE AND / OR REPAIR           MULTI-FAMILY DWELLING
# 12389  RESTORE AND / OR REPAIR           MULTI-FAMILY DWELLING
# 12394                      ADD  COMMERCIAL MISCELLANEOUS STRUC
# 12476                    ALTER           MULTI-FAMILY DWELLING
# 12971                CONSTRUCT                  RETAINING WALL
# ...                        ...                             ...
# 22631                    ALTER                STORAGE BUILDING
# 22695                    ALTER                STORAGE BUILDING
# 23357                    ALTER                      RESTAURANT
# 23898                    ALTER               BUSINESS BUILDING
# 24294  RESTORE AND / OR REPAIR               BUSINESS BUILDING
# 26795  RESTORE AND / OR REPAIR                          GARAGE
# 26796  RESTORE AND / OR REPAIR                          GARAGE
# 27771                    ALTER  MULTIFAMILY DWELLING HIGH RISE
# 28405                    ALTER               BUSINESS BUILDING
# 28622                CONSTRUCT  COMMERCIAL MISCELLANEOUS STRUC
#
#                                                 Location
# 8480   7500 WOODMONT\nBETHESDA, MD 20814\n(38.984252,...
# 9825   12500 PARK POTOMAC\nPOTOMAC, MD 20854\n(39.060...
# 10775  12500 PARK POTOMAC\nPOTOMAC, MD 20854\n(39.060...
# 11445  12500 PARK POTOMAC\nPOTOMAC, MD 20854\n(39.060...
# 11626       21040 HENDERSON CORNER\nGERMANTOWN, MD 20876
# 12038  14201 GEORGIA AVE\nSILVER SPRING, MD 20906\n(3...
# 12389  14201 GEORGIA AVE\nSILVER SPRING, MD 20906\n(3...
# 12394       21040 HENDERSON CORNER\nGERMANTOWN, MD 20876
# 12476  7500 WOODMONT\nBETHESDA, MD 20814\n(38.984252,...
# 12971       21040 HENDERSON CORNER\nGERMANTOWN, MD 20876
# ...                                                  ...
# 22631  7101 DEMOCRACY\nBETHESDA, MD 20817\n(39.0242, ...
# 22695  7101 DEMOCRACY\nBETHESDA, MD 20817\n(39.0242, ...
# 23357  7101 DEMOCRACY\nBETHESDA, MD 20817\n(39.0242, ...
# 23898  6420 ROCKLEDGE\nBETHESDA, MD 20817\n(39.024646...
# 24294  7500 WOODMONT\nBETHESDA, MD 20814\n(38.984252,...
# 26795              12500 PARK POTOMAC\nPOTOMAC, MD 20854
# 26796              12500 PARK POTOMAC\nPOTOMAC, MD 20854
# 27771              12500 PARK POTOMAC\nPOTOMAC, MD 20854
# 28405  6011 EXECUTIVE\nROCKVILLE 20854\n(39.048842, -...
# 28622  11160 VEIRS MILL\nWHEATON, MD 20902\n(39.03832...
#
# [48 rows x 18 columns]

# %%
D2.dropna(subset=[ 'W_type'], inplace=True)
D2.shape
# Out:
# (27633, 18)

# %%
print("Old data frame length:", len(cp), "\nNew data frame length:",  
       len(D2), "\nNumber of rows with at least 1 NA value: ", 
       (len(cp)-len(D2)))
# Out:
# Old data frame length: 28806
# New data frame length: 27633
# Number of rows with at least 1 NA value:  1173

# %%
cp1["Null Column"]= None
print(cp1.columns.values, "\n", cp1.columns.values)
# Out:
# ['P_num' 'Status' 'St_num' 'Pre_d' 'St_name' 'St_suf' 'Post_d' 'City'
#  'State' 'Zip' 'A_date' 'I_date' 'F_date' 'Building_area' 'Decl_v' 'Desc'
#  'A_type' 'W_type' 'U_code' 'Location' 'Null Column']
#  ['P_num' 'Status' 'St_num' 'Pre_d' 'St_name' 'St_suf' 'Post_d' 'City'
#  'State' 'Zip' 'A_date' 'I_date' 'F_date' 'Building_area' 'Decl_v' 'Desc'
#  'A_type' 'W_type' 'U_code' 'Location' 'Null Column']

# %% [markdown]
# In counclusion much has already been done to remove the 1600 rows with missing data.
# Now to filter and see how many of the same type

# %% [markdown]
# Dennis said some of the permit locations are off how to fix that each permit should line up with its zip code

# %% [markdown]
# First I am going to see how many permits are in each city

# %%
D2.City.value_counts()
# Out:
# SILVER SPRING       6913
# BETHESDA            4471
# ROCKVILLE           4141
# GERMANTOWN          2807
# CLARKSBURG          1930
# GAITHERSBURG        1347
# CHEVY CHASE         1237
# POTOMAC             1042
# OLNEY                554
# KENSINGTON           536
#                     ...
# GARRETT PARK           9
# GLEN ECHO              8
# WASHINGTON GROVE       6
# HIGHLAND               4
# NORTH POTOMAC          3
# BELTSVILLE             2
# ASPEN HILL             2
# SILVERSPRING           1
# DAWSONVILLE            1
# BRINKLOW               1
# Name: City, Length: 39, dtype: int64

# %%
D2.City.replace(['SILVERSPRING'], ['SILVER SPRING'], inplace=True)

# %% [markdown]
# So Dennis said that some of the permit data was not properly matched to its city.
# I found a great package that is called uszipcode. The package retrives data from zip code information or location data.

# %%
# Testing out package
from uszipcode import SearchEngine
search = SearchEngine(simple_zipcode=True)
zipcode = search.by_zipcode("20902")
zipcode.values()
# Out:
# ['20902',
#  'Standard',
#  'Silver Spring',
#  'Silver Spring, MD',
#  ['Silver Spring', 'Wheaton'],
#  'Montgomery County',
#  'MD',
#  39.04,
#  -77.04,
#  'Eastern',
#  3.0,
#  ['240', '301'],
#  48841,
#  6443.0,
#  7.58,
#  0.03,
#  17073,
#  16271,
#  355500,
#  76646,
#  -77.082046,
#  -77.006729,
#  39.066505,
#  39.015571]

# %%
#Creating list to store new values based off data's Zip column
new_location = []
search = SearchEngine(simple_zipcode=True)
# Iterating through each row 
for index,row in D2.iterrows():
    current_city = row['Zip']
    zipcode = search.by_zipcode(current_city)
    new_location.append(zipcode.values()[2])

# %%
# Creating new column in data set for the data retrived via the package
D2['NewCity'] = new_location

# %%
[i*2 for i in D2.P_num]
# Out:
# [417354,
#  417356,
#  417358,
#  417378,
#  417380,
#  417382,
#  417384,
#  417432,
#  417478,
#  417544,
#  417546,
#  417564,
#  417566,
#  417852,
#  417858,
#  417902,
#  417904,
#  417908,
#  418104,
#  418106,
#  418154,
#  418170,
#  418208,
#  418546,
#  418550,
#  418556,
#  418866,
#  418984,
#  418986,
#  418994,
#  418996,
#  419008,
#  419198,
#  419298,
#  419320,
#  419346,
#  419372,
#  419556,
#  419750,
#  419820,
#  419822,
#  419830,
#  419838,
#  419840,
#  419888,
#  419958,
#  419960,
#  419978,
#  420054,
#  420134,
#  420162,
#  420250,
#  420340,
#  420368,
#  420598,
#  420646,
#  420656,
#  420696,
#  420702,
#  420706,
#  420710,
#  420716,
#  420740,
#  420816,
#  420850,
#  420922,
#  420982,
#  420994,
#  421074,
#  421076,
#  421192,
#  421244,
#  421276,
#  421288,
#  421296,
#  421384,
#  421446,
#  421472,
#  421478,
#  421504,
#  421538,
#  421736,
#  421740,
#  421742,
#  421744,
#  421746,
#  421748,
#  421844,
#  421846,
#  421850,
#  421852,
#  421856,
#  421858,
#  421860,
#  421862,
#  421864,
#  421866,
#  421868,
#  421870,
#  421872,
#  421874,
#  421906,
#  421908,
#  421910,
#  421914,
#  421916,
#  421918,
#  421920,
#  421922,
#  421924,
#  421926,
#  421928,
#  421966,
#  422036,
#  422178,
#  422264,
#  422290,
#  422336,
#  422372,
#  422490,
#  422494,
#  422644,
#  423190,
#  423206,
#  423208,
#  423252,
#  423256,
#  423304,
#  423588,
#  423634,
#  423636,
#  423676,
#  423678,
#  423790,
#  423798,
#  423808,
#  423814,
#  423994,
#  424364,
#  424372,
#  424382,
#  424436,
#  424480,
#  424536,
#  424600,
#  424628,
#  424796,
#  425086,
#  425170,
#  425196,
#  425208,
#  425458,
#  425486,
#  425504,
#  425582,
#  425630,
#  425784,
#  425836,
#  426006,
#  426038,
#  426208,
#  426222,
#  426766,
#  426784,
#  426806,
#  426822,
#  426958,
#  426966,
#  427032,
#  427036,
#  427078,
#  427232,
#  427240,
#  427248,
#  427308,
#  427310,
#  427418,
#  427656,
#  427738,
#  427744,
#  427788,
#  427852,
#  427974,
#  428234,
#  428314,
#  428340,
#  428378,
#  428394,
#  428424,
#  428486,
#  428598,
#  428966,
#  428974,
#  428990,
#  429000,
#  429044,
#  429052,
#  429062,
#  429082,
#  429108,
#  429114,
#  429116,
#  429124,
#  429128,
#  429130,
#  429132,
#  429136,
#  429144,
#  429150,
#  429158,
#  429164,
#  429176,
#  429188,
#  429194,
#  429204,
#  429206,
#  429230,
#  429234,
#  429322,
#  429338,
#  429536,
#  429676,
#  429722,
#  429960,
#  429980,
#  430010,
#  430052,
#  430068,
#  430092,
#  430160,
#  430294,
#  430434,
#  430446,
#  430520,
#  430642,
#  430726,
#  430792,
#  430900,
#  430914,
#  430922,
#  430928,
#  430970,
#  431128,
#  431226,
#  431250,
#  431362,
#  431566,
#  431568,
#  431676,
#  431808,
#  432204,
#  432286,
#  432296,
#  432526,
#  432642,
#  432680,
#  432942,
#  432948,
#  432950,
#  432952,
#  432956,
#  433088,
#  433326,
#  433348,
#  433798,
#  433842,
#  433846,
#  434068,
#  434120,
#  434130,
#  434172,
#  434264,
#  434292,
#  434296,
#  434304,
#  434306,
#  434336,
#  434424,
#  434456,
#  434460,
#  434466,
#  434558,
#  434642,
#  434714,
#  434720,
#  434736,
#  434828,
#  434848,
#  434888,
#  434906,
#  434986,
#  435002,
#  435020,
#  435022,
#  435024,
#  435026,
#  435034,
#  435096,
#  435100,
#  435164,
#  435170,
#  435272,
#  435298,
#  435304,
#  435338,
#  435396,
#  435406,
#  435502,
#  435514,
#  435598,
#  435774,
#  435804,
#  435850,
#  436146,
#  436344,
#  436384,
#  436444,
#  436474,
#  436574,
#  436592,
#  436606,
#  436624,
#  436630,
#  436772,
#  436780,
#  436816,
#  436844,
#  436894,
#  436902,
#  436966,
#  437078,
#  437126,
#  437342,
#  437344,
#  437506,
#  437568,
#  437572,
#  437574,
#  437576,
#  437578,
#  437648,
#  437686,
#  437716,
#  437752,
#  437786,
#  437940,
#  438018,
#  438068,
#  438074,
#  438164,
#  438188,
#  438198,
#  438208,
#  438258,
#  438270,
#  438336,
#  438390,
#  438510,
#  438512,
#  438662,
#  438766,
#  438828,
#  438876,
#  438932,
#  439156,
#  439182,
#  439238,
#  439314,
#  439364,
#  439378,
#  439562,
#  439598,
#  439700,
#  439752,
#  439790,
#  439888,
#  439890,
#  439892,
#  439896,
#  440084,
#  440120,
#  440216,
#  440236,
#  440414,
#  440446,
#  440468,
#  440486,
#  440502,
#  440618,
#  440724,
#  440854,
#  440878,
#  440896,
#  440918,
#  441136,
#  441184,
#  441254,
#  441428,
#  441444,
#  441448,
#  441558,
#  441582,
#  441632,
#  441756,
#  441788,
#  441806,
#  441906,
#  441916,
#  441918,
#  441920,
#  441936,
#  441992,
#  442000,
#  442056,
#  442246,
#  442854,
#  442944,
#  442966,
#  443020,
#  443026,
#  443084,
#  443104,
#  443130,
#  443136,
#  443304,
#  443312,
#  443356,
#  443400,
#  443422,
#  443454,
#  443564,
#  443616,
#  443750,
#  443816,
#  443834,
#  443838,
#  443918,
#  443956,
#  443968,
#  444028,
#  444110,
#  444114,
#  444122,
#  444166,
#  444232,
#  444252,
#  444264,
#  444282,
#  444300,
#  444312,
#  444430,
#  444540,
#  444686,
#  444698,
#  444762,
#  445176,
#  445180,
#  445396,
#  445620,
#  445672,
#  445682,
#  445958,
#  445964,
#  446196,
#  446204,
#  446404,
#  446432,
#  446598,
#  446648,
#  446702,
#  446808,
#  446840,
#  446842,
#  446886,
#  446942,
#  446956,
#  447018,
#  447148,
#  447226,
#  447294,
#  447368,
#  447514,
#  447696,
#  447976,
#  448088,
#  448104,
#  448110,
#  448338,
#  448548,
#  448558,
#  448780,
#  448830,
#  448832,
#  449076,
#  449190,
#  449402,
#  449426,
#  449558,
#  449692,
#  449706,
#  449710,
#  449846,
#  450006,
#  450032,
#  450034,
#  450044,
#  450046,
#  450050,
#  450066,
#  450082,
#  450094,
#  450112,
#  450136,
#  450142,
#  450148,
#  450150,
#  450152,
#  450160,
#  450162,
#  450262,
#  450362,
#  450560,
#  450612,
#  450626,
#  450632,
#  450750,
#  450874,
#  450938,
#  451044,
#  451062,
#  451110,
#  451334,
#  451532,
#  451616,
#  451636,
#  451738,
#  452004,
#  452012,
#  452066,
#  452210,
#  452220,
#  452314,
#  452406,
#  452412,
#  452470,
#  452472,
#  452532,
#  452568,
#  452690,
#  452700,
#  452896,
#  452954,
#  452958,
#  452974,
#  452984,
#  453010,
#  453030,
#  453522,
#  453674,
#  454160,
#  454222,
#  454454,
#  454676,
#  454734,
#  454744,
#  454766,
#  454776,
#  454780,
#  454782,
#  454784,
#  454788,
#  454792,
#  454798,
#  454800,
#  454802,
#  454806,
#  454808,
#  454810,
#  454970,
#  454974,
#  454980,
#  455094,
#  455146,
#  455150,
#  455358,
#  455376,
#  455722,
#  455742,
#  455744,
#  455746,
#  455750,
#  455828,
#  456110,
#  456134,
#  456218,
#  456236,
#  456278,
#  458386,
#  458540,
#  458626,
#  458826,
#  458906,
#  458908,
#  458916,
#  458920,
#  458970,
#  459026,
#  459186,
#  459190,
#  459250,
#  459358,
#  459400,
#  459632,
#  459668,
#  459768,
#  459830,
#  459844,
#  459846,
#  459896,
#  460026,
#  460036,
#  460078,
#  460158,
#  460312,
#  460316,
#  460510,
#  460550,
#  460616,
#  460648,
#  460654,
#  460746,
#  460924,
#  461066,
#  461320,
#  461324,
#  461328,
#  461384,
#  461430,
#  461468,
#  461478,
#  461746,
#  461770,
#  461836,
#  461846,
#  461864,
#  461866,
#  461868,
#  461870,
#  461872,
#  461874,
#  461928,
#  461942,
#  461950,
#  462008,
#  462012,
#  462058,
#  462122,
#  462146,
#  462210,
#  462232,
#  462450,
#  462662,
#  462742,
#  462744,
#  462776,
#  462896,
#  463084,
#  463106,
#  463110,
#  463136,
#  463196,
#  463216,
#  463268,
#  463278,
#  463286,
#  463364,
#  463422,
#  463450,
#  463480,
#  463486,
#  463652,
#  463712,
#  463946,
#  464024,
#  464032,
#  464036,
#  464096,
#  464168,
#  464266,
#  464316,
#  464320,
#  464578,
#  464652,
#  464836,
#  464858,
#  464862,
#  464952,
#  464958,
#  465000,
#  465056,
#  465210,
#  465218,
#  465308,
#  465378,
#  465410,
#  465526,
#  465534,
#  465598,
#  465632,
#  465744,
#  465772,
#  465800,
#  465852,
#  465880,
#  465886,
#  465906,
#  466068,
#  466070,
#  466072,
#  466074,
#  466076,
#  466078,
#  466080,
#  466082,
#  466084,
#  466086,
#  466088,
#  466090,
#  466092,
#  466096,
#  466098,
#  466100,
#  466110,
#  466112,
#  466284,
#  466326,
#  466344,
#  466388,
#  466554,
#  466700,
#  466702,
#  466704,
#  466706,
#  466708,
#  466710,
#  466712,
#  466714,
#  466716,
#  466718,
#  466720,
#  466722,
#  466724,
#  466726,
#  466728,
#  466730,
#  466732,
#  466734,
#  466736,
#  466738,
#  466740,
#  466742,
#  466744,
#  466746,
#  466748,
#  466886,
#  466916,
#  466920,
#  466956,
#  467008,
#  467048,
#  467158,
#  467160,
#  467162,
#  467260,
#  467292,
#  467296,
#  467300,
#  467346,
#  467356,
#  467362,
#  467406,
#  467548,
#  467738,
#  467774,
#  467828,
#  468048,
#  468050,
#  468100,
#  468152,
#  468158,
#  468194,
#  468386,
#  468402,
#  468408,
#  468638,
#  468936,
#  468972,
#  469008,
#  469060,
#  469110,
#  469112,
#  469114,
#  469136,
#  469164,
#  469202,
#  469266,
#  469334,
#  469370,
#  469380,
#  469414,
#  469418,
#  469454,
#  469620,
#  469642,
#  469756,
#  469882,
#  469892,
#  470132,
#  470228,
#  470238,
#  470248,
#  470250,
#  470396,
#  470516,
#  470610,
#  470684,
#  470732,
#  470996,
#  470998,
#  471002,
#  471004,
#  471030,
#  471088,
#  471090,
#  471322,
#  471404,
#  471454,
#  471468,
#  471470,
#  471474,
#  471540,
#  471542,
#  471546,
#  471550,
#  471622,
#  471778,
#  471782,
#  471784,
#  471816,
#  471842,
#  471844,
#  471910,
#  472016,
#  472168,
#  472232,
#  472302,
#  472308,
#  472358,
#  472360,
#  472532,
#  472562,
#  472574,
#  472748,
#  472766,
#  472974,
#  473076,
#  473144,
#  473152,
#  473162,
#  473338,
#  473472,
#  473490,
#  473502,
#  473504,
#  473512,
#  473514,
#  473516,
#  473518,
#  473652,
#  473656,
#  473682,
#  473720,
#  473738,
#  473784,
#  473788,
#  473790,
#  473804,
#  473834,
#  474044,
#  474232,
#  474234,
#  474236,
#  474328,
#  474342,
#  474410,
#  474554,
#  474562,
#  474602,
#  474614,
#  474628,
#  474650,
#  474658,
#  474810,
#  474878,
#  474934,
#  474936,
#  475052,
#  475216,
#  475240,
#  475302,
#  475304,
#  475308,
#  475310,
#  475312,
#  475314,
#  475316,
#  475320,
#  475322,
#  475324,
#  475328,
#  475330,
#  475332,
#  475334,
#  475336,
#  475338,
#  475390,
#  475410,
#  475432,
#  475486,
#  475800,
#  475814,
#  475816,
#  475872,
#  475880,
#  475988,
#  476430,
#  476440,
#  476534,
#  476542,
#  476560,
#  476564,
#  476582,
#  476620,
#  476742,
#  476880,
#  477102,
#  477106,
#  477114,
#  477224,
#  477248,
#  477342,
#  477366,
#  477372,
#  477376,
#  477436,
#  477460,
#  477494,
#  477518,
#  477576,
#  477690,
#  477794,
#  477814,
#  477834,
#  478078,
#  478214,
#  478218,
#  478222,
#  478270,
#  478414,
#  478456,
#  478492,
#  478616,
#  478652,
#  478736,
#  478760,
#  478812,
#  478888,
#  478898,
#  478930,
#  479002,
#  479118,
#  479246,
#  479336,
#  479420,
#  479644,
#  479878,
#  479956,
#  480084,
#  480090,
#  480116,
#  480120,
#  480144,
#  480188,
#  480250,
#  480288,
#  480290,
#  480628,
#  480750,
#  480768,
#  480818,
#  ...]

# %%
# Iterating throught each row to see the difference between the data's city info and the info the package retrived
for index,row in D2.iterrows():
    if row['NewCity'] != None:
        old = row['City'].lower()
        new = row['NewCity'].lower()
        if old != new:
            print(old,new)
# Out:
# darnestown gaithersburg
# silver spring takoma park
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# silver spring takoma park
# rockville derwood
# silver spring takoma park
# bethesda potomac
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# rockville derwood
# laytonsville gaithersburg
# rockville derwood
# wheaton silver spring
# wheaton silver spring
# darnestown gaithersburg
# darnestown gaithersburg
# darnestown gaithersburg
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# silver spring takoma park
# clarksburg damascus
# rockville derwood
# laytonsville gaithersburg
# rockville derwood
# rockville derwood
# rockville derwood
# rockville gaithersburg
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# clarksburg damascus
# clarksburg damascus
# rockville potomac
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville potomac
# rockville potomac
# dawsonville germantown
# rockville derwood
# rockville derwood
# silver spring takoma park
# gaithersburg montgomery village
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# germantown gaithersburg
# rockville derwood
# rockville derwood
# silver spring takoma park
# clarksburg germantown
# clarksburg germantown
# clarksburg germantown
# clarksburg germantown
# wheaton silver spring
# rockville derwood
# sandy spring silver spring
# rockville gaithersburg
# wheaton silver spring
# wheaton silver spring
# wheaton silver spring
# beallsville dickerson
# aspen hill silver spring
# rockville derwood
# laytonsville gaithersburg
# rockville derwood
# rockville derwood
# gaithersburg montgomery village
# rockville derwood
# rockville potomac
# rockville potomac
# rockville potomac
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# north bethesda rockville
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# laytonsville gaithersburg
# rockville derwood
# north bethesda rockville
# rockville derwood
# wheaton silver spring
# north bethesda rockville
# rockville derwood
# rockville derwood
# kensington bethesda
# rockville derwood
# clarksburg germantown
# laytonsville gaithersburg
# rockville derwood
# rockville derwood
# germantown gaithersburg
# germantown gaithersburg
# rockville derwood
# rockville derwood
# gaithersburg montgomery village
# rockville potomac
# rockville derwood
# silver spring takoma park
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# silver spring takoma park
# rockville potomac
# rockville derwood
# bethesda chevy chase
# rockville derwood
# rockville derwood
# rockville derwood
# bethesda chevy chase
# rockville derwood
# gaithersburg montgomery village
# silver spring takoma park
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville potomac
# rockville potomac
# darnestown gaithersburg
# gaithersburg montgomery village
# rockville derwood
# bethesda rockville
# clarksburg damascus
# darnestown gaithersburg
# bethesda rockville
# rockville derwood
# north bethesda rockville
# rockville derwood
# north bethesda rockville
# rockville derwood
# clarksburg damascus
# north potomac gaithersburg
# rockville bethesda
# rockville derwood
# rockville derwood
# rockville derwood
# laytonsville gaithersburg
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville gaithersburg
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# north bethesda rockville
# north bethesda rockville
# wheaton silver spring
# rockville derwood
# rockville derwood
# north bethesda rockville
# rockville derwood
# rockville derwood
# darnestown gaithersburg
# rockville derwood
# darnestown germantown
# rockville derwood
# rockville derwood
# rockville derwood
# rockville potomac
# rockville derwood
# olney sandy spring
# silver spring takoma park
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# bethesda rockville
# wheaton silver spring
# wheaton silver spring
# rockville derwood
# darnestown germantown
# rockville derwood
# silver spring takoma park
# rockville derwood
# north bethesda rockville
# rockville derwood
# rockville derwood
# montgomery village gaithersburg
# north bethesda rockville
# rockville derwood
# wheaton silver spring
# rockville derwood
# montgomery village gaithersburg
# rockville derwood
# rockville derwood
# gaithersburg montgomery village
# rockville potomac
# rockville bethesda
# rockville derwood
# rockville derwood
# rockville derwood
# silver spring burtonsville
# takoma park silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# olney sandy spring
# silver spring takoma park
# rockville derwood
# kensington bethesda
# gaithersburg montgomery village
# rockville derwood
# rockville potomac
# silver spring takoma park
# silver spring takoma park
# rockville derwood
# rockville derwood
# north bethesda rockville
# rockville derwood
# gaithersburg montgomery village
# rockville potomac
# wheaton silver spring
# rockville derwood
# rockville potomac
# rockville derwood
# brookeville burtonsville
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# silver spring takoma park
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# silver spring takoma park
# rockville derwood
# rockville derwood
# darnestown gaithersburg
# silver spring takoma park
# gaithersburg montgomery village
# rockville derwood
# wheaton silver spring
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# darnestown gaithersburg
# rockville derwood
# rockville derwood
# rockville derwood
# takoma park silver spring
# north bethesda rockville
# wheaton silver spring
# wheaton silver spring
# wheaton silver spring
# silver spring takoma park
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# silver spring takoma park
# gaithersburg montgomery village
# north bethesda rockville
# wheaton silver spring
# north bethesda rockville
# rockville derwood
# rockville potomac
# rockville bethesda
# rockville bethesda
# derwood gaithersburg
# takoma park silver spring
# chevy chase bethesda
# rockville bethesda
# rockville bethesda
# rockville bethesda
# rockville bethesda
# rockville bethesda
# rockville bethesda
# silver spring takoma park
# rockville bethesda
# rockville bethesda
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# silver spring takoma park
# rockville derwood
# chevy chase bethesda
# derwood gaithersburg
# rockville derwood
# rockville bethesda
# rockville derwood
# rockville derwood
# north bethesda rockville
# silver spring beltsville
# north bethesda rockville
# wheaton silver spring
# rockville derwood
# rockville bethesda
# rockville bethesda
# rockville derwood
# rockville bethesda
# clarksburg damascus
# silver spring burtonsville
# laytonsville gaithersburg
# rockville derwood
# rockville derwood
# darnestown gaithersburg
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# bethesda chevy chase
# wheaton silver spring
# rockville potomac
# bethesda rockville
# rockville derwood
# rockville derwood
# kensington bethesda
# rockville derwood
# silver spring takoma park
# rockville derwood
# rockville derwood
# wheaton silver spring
# gaithersburg montgomery village
# rockville derwood
# rockville derwood
# north bethesda rockville
# rockville derwood
# rockville derwood
# clarksburg damascus
# rockville bethesda
# rockville derwood
# rockville bethesda
# silver spring takoma park
# rockville derwood
# kensington silver spring
# rockville derwood
# rockville derwood
# kensington bethesda
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# olney sandy spring
# rockville derwood
# bethesda rockville
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville bethesda
# darnestown gaithersburg
# gaithersburg montgomery village
# wheaton silver spring
# silver spring takoma park
# rockville potomac
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# north bethesda rockville
# rockville derwood
# rockville derwood
# rockville derwood
# silver spring takoma park
# wheaton silver spring
# rockville derwood
# chevy chase bethesda
# bethesda chevy chase
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# bethesda chevy chase
# north potomac gaithersburg
# rockville derwood
# wheaton silver spring
# rockville derwood
# gaithersburg montgomery village
# wheaton silver spring
# wheaton silver spring
# silver spring takoma park
# rockville derwood
# rockville derwood
# gaithersburg montgomery village
# rockville derwood
# silver spring takoma park
# chevy chase bethesda
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# bethesda rockville
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# brinklow ashton
# rockville derwood
# rockville bethesda
# rockville derwood
# clarksburg damascus
# laytonsville gaithersburg
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville potomac
# rockville derwood
# rockville derwood
# rockville derwood
# north bethesda rockville
# rockville bethesda
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# silver spring takoma park
# chevy chase bethesda
# chevy chase bethesda
# rockville derwood
# clarksburg damascus
# rockville derwood
# rockville bethesda
# silver spring takoma park
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# north bethesda rockville
# rockville derwood
# gaithersburg montgomery village
# rockville derwood
# north bethesda rockville
# north bethesda rockville
# poolesville boyds
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# silver spring takoma park
# rockville derwood
# rockville derwood
# wheaton silver spring
# wheaton silver spring
# rockville derwood
# rockville derwood
# north bethesda rockville
# north bethesda bethesda
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# gaithersburg montgomery village
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# gaithersburg montgomery village
# rockville bethesda
# rockville bethesda
# silver spring takoma park
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville potomac
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# gaithersburg montgomery village
# rockville potomac
# rockville derwood
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# rockville derwood
# silver spring takoma park
# rockville derwood
# wheaton silver spring
# rockville potomac
# north bethesda rockville
# rockville derwood
# north bethesda rockville
# rockville derwood
# rockville derwood
# kensington bethesda
# bethesda chevy chase
# chevy chase bethesda
# rockville derwood
# north bethesda rockville
# north bethesda rockville
# rockville derwood
# wheaton silver spring
# wheaton silver spring
# wheaton silver spring
# north bethesda rockville
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville potomac
# rockville derwood
# wheaton silver spring
# north potomac gaithersburg
# brookeville burtonsville
# gaithersburg montgomery village
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville potomac
# rockville derwood
# rockville derwood
# bethesda rockville
# wheaton silver spring
# rockville derwood
# rockville derwood
# darnestown germantown
# gaithersburg montgomery village
# north bethesda rockville
# rockville bethesda
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# kensington bethesda
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# rockville derwood
# rockville gaithersburg
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# north bethesda rockville
# chevy chase bethesda
# wheaton silver spring
# rockville derwood
# gaithersburg montgomery village
# wheaton silver spring
# kensington bethesda
# kensington bethesda
# kensington bethesda
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# chevy chase bethesda
# north bethesda rockville
# wheaton silver spring
# chevy chase bethesda
# chevy chase bethesda
# north bethesda rockville
# chevy chase bethesda
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# north bethesda rockville
# rockville derwood
# rockville derwood
# rockville derwood
# north bethesda rockville
# rockville derwood
# rockville derwood
# silver spring takoma park
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# gaithersburg montgomery village
# rockville derwood
# wheaton silver spring
# north bethesda rockville
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# rockville derwood
# rockville derwood
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville potomac
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# gaithersburg montgomery village
# rockville derwood
# silver spring takoma park
# montgomery village gaithersburg
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville potomac
# north bethesda rockville
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# gaithersburg montgomery village
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# north bethesda rockville
# rockville derwood
# wheaton silver spring
# montgomery village gaithersburg
# rockville bethesda
# rockville derwood
# darnestown gaithersburg
# darnestown gaithersburg
# north bethesda rockville
# rockville potomac
# rockville derwood
# rockville bethesda
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville bethesda
# rockville derwood
# rockville bethesda
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# gaithersburg montgomery village
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# aspen hill silver spring
# rockville derwood
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville bethesda
# rockville bethesda
# rockville derwood
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# darnestown gaithersburg
# rockville bethesda
# rockville bethesda
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# rockville derwood
# rockville bethesda
# rockville bethesda
# rockville derwood
# rockville derwood
# rockville derwood
# wheaton silver spring
# rockville derwood
# rockville bethesda
# wheaton silver spring
# rockville derwood
# rockville derwood
# gaithersburg montgomery village
# wheaton silver spring
# gaithersburg montgomery village
# rockville derwood
# rockville derwood
# rockville derwood
# north bethesda rockville
# rockville derwood
# rockville derwood
# rockville derwood
# rockville derwood
# rockville bethesda
# rockville derwood
# rockville derwood
# rockville derwood
# rockville bethesda
# darnestown gaithersburg
# wheaton silver spring
# wheaton silver spring
# rockville derwood
# rockville derwood
# chevy chase bethesda
# wheaton silver spring
# rockville derwood
# rockville derwood
# rockville potomac
# rockville derwood
# north bethesda rockville
# wheaton silver spring
# wheaton silver spring
# rockville derwood

# %%
from IPython.display import display
display(D2.NewCity.value_counts())
display(D2.City.value_counts())
# Out:
# Silver Spring       6954
# Bethesda            4513
# Rockville           3471
# Germantown          2802
# Clarksburg          1916
# Gaithersburg        1355
# Chevy Chase         1229
# Potomac             1069
# Derwood              661
# Takoma Park          563
#                     ...
# Cabin John            37
# Ashton                36
# Spencerville          18
# Beallsville           16
# Mount Airy            15
# Garrett Park           9
# Glen Echo              8
# Highland               4
# Beltsville             3
# Washington Grove       2
# Name: NewCity, Length: 30, dtype: int64
# SILVER SPRING       6914
# BETHESDA            4471
# ROCKVILLE           4141
# GERMANTOWN          2807
# CLARKSBURG          1930
# GAITHERSBURG        1347
# CHEVY CHASE         1237
# POTOMAC             1042
# OLNEY                554
# KENSINGTON           536
#                     ...
# LAYTONSVILLE          10
# GARRETT PARK           9
# GLEN ECHO              8
# WASHINGTON GROVE       6
# HIGHLAND               4
# NORTH POTOMAC          3
# BELTSVILLE             2
# ASPEN HILL             2
# DAWSONVILLE            1
# BRINKLOW               1
# Name: City, Length: 38, dtype: int64

# %% [markdown]
#           New City        Old City
# * Silver Spring         6954     * SILVER SPRING         6913
# * Bethesda              4513     * BETHESDA              4471
# * Rockville             3471     * ROCKVILLE             4141
# * Germantown            2803     * GERMANTOWN            2808
# - Clarksburg            1916     * CLARKSBURG            1930
# * Gaithersburg          1356     * GAITHERSBURG          1348
# * Chevy Chase           1229     * CHEVY CHASE           1237
# - Potomac               1070     * POTOMAC               1043

# %% [markdown]
# So the discrepency is not so dramatic. The change in number mostly comes from Rockville losing permits to Deerwood, which had almost no permits before.

# %% [markdown]
# So now to deal with the the location column in the data frame. The "location" column appears to be compiled from the all of the location data present in the data set, such as address street number ect.
# * To make usable Longitude and Latitude I split the location string twice.
# * Then I made new columns for the address and and LnL data

# %%
E2 = D2.Location.str.split("(", n =1, expand = True)
# making separate logitude/ladditude column from new data frame 
D2["Address"]= E2[0] 
  
# making separate Address column from new data frame 
D2["LL"]= E2[1] 
  
# Dropping old Name columns 
D2.drop(columns =["Location"], inplace = True) 
# adding pertheses back in
# df display 
D2
# Out:
#            P_num   Status St_num Pre_d         St_name St_suf Post_d  \
# 0         208677  Finaled  19850   N/A         CENTURY   BLVD    N/A
# 1         208678  Finaled  12901   N/A        PINNACLE     DR    N/A
# 2         208679  Finaled  12903   N/A        PINNACLE     DR    N/A
# 3         208689  Finaled  12907   N/A        PINNACLE     DR    N/A
# 4         208690  Finaled  12909   N/A        PINNACLE     DR    N/A
# 5         208691  Finaled  12925   N/A        PINNACLE     DR    N/A
# 6         208692   Issued  12935   N/A        PINNACLE     DR    N/A
# 7         208716  Finaled  16507     S       FREDERICK    AVE    N/A
# 8         208739  Finaled   8600   N/A  OLD GEORGETOWN     RD    N/A
# 9         208772  Finaled  12955   N/A        PINNACLE     DR    N/A
# ...          ...      ...    ...   ...             ...    ...    ...
# 28768     894100     Open  14239   N/A       DOWITCHER    WAY    N/A
# 28769     894102     Open  14236   N/A       DOWITCHER    WAY    N/A
# 28771     894147     Open  11800   N/A            TECH     RD    N/A
# 28772     894159     Open  19300   N/A         GEORGIA    AVE    N/A
# 28774     894298     Open   3415   N/A       OLANDWOOD     CT    N/A
# 28775     894346     Open   1776     E       JEFFERSON     ST    N/A
# 28776     894352     Open   5635   N/A         FISHERS     LN    N/A
# 28778     894436     Open      1   N/A       DISCOVERY     PL    N/A
# 28804     894600     Open    201   N/A    VALLEY BROOK     DR    N/A
# 28805  999211064     Open  14014   N/A     CONNECTICUT    AVE    N/A
#
#                 City    Zip     A_date     I_date               F_date  \
# 0         GERMANTOWN  20874 2000-01-03 2000-12-14  2001-10-10 00:00:00
# 1         GERMANTOWN  20874 2000-01-03 2000-12-14  2001-10-11 00:00:00
# 2         GERMANTOWN  20874 2000-01-03 2000-12-14  2001-10-12 00:00:00
# 3         GERMANTOWN  20874 2000-01-03 2000-12-14  2002-01-31 00:00:00
# 4         GERMANTOWN  20874 2000-01-03 2000-12-14  2002-01-29 00:00:00
# 5         GERMANTOWN  20874 2000-01-03 2000-12-14  2002-01-25 00:00:00
# 6         GERMANTOWN  20874 2000-01-03 2000-12-14                  N/A
# 7       GAITHERSBURG  20877 2000-01-03 2000-01-03  2000-01-19 00:00:00
# 8           BETHESDA  20817 2000-01-04 2000-01-27  2000-10-31 00:00:00
# 9         GERMANTOWN  20874 2000-01-04 2000-12-14  2001-12-21 00:00:00
# ...              ...    ...        ...        ...                  ...
# 28768          BOYDS  20841 2019-10-24        NaT                  N/A
# 28769          BOYDS  20841 2019-10-24        NaT                  N/A
# 28771  SILVER SPRING  20904 2019-10-24        NaT                  N/A
# 28772    BROOKEVILLE  20833 2019-10-24        NaT                  N/A
# 28774          OLNEY  20832 2019-10-25        NaT                  N/A
# 28775      ROCKVILLE  20852 2019-10-25        NaT                  N/A
# 28776      ROCKVILLE  20852 2019-10-25        NaT                  N/A
# 28778  SILVER SPRING  20910 2019-10-28        NaT                  N/A
# 28804  SILVER SPRING  20904 2019-10-28        NaT                  N/A
# 28805  SILVER SPRING  20906 2001-01-31        NaT                  N/A
#
#        Building_area      Decl_v  \
# 0            42600.0  1000000.00
# 1            42600.0  1000000.00
# 2            42600.0  1000000.00
# 3            63300.0  1500000.00
# 4            63300.0  1500000.00
# 5            63300.0  1500000.00
# 6            63300.0  1500000.00
# 7             3000.0    10000.00
# 8            10350.0   110000.00
# 9            36400.0   750000.00
# ...              ...         ...
# 28768          810.0   156854.00
# 28769          800.0   156854.00
# 28771        61257.0   742000.00
# 28772            0.0   196508.02
# 28774         1547.0   160000.00
# 28775          480.0   100000.00
# 28776        28510.0   210000.00
# 28778        39000.0  1000000.00
# 28804          625.0    39500.00
# 28805            1.0        1.00
#
#                                                     Desc  \
# 0                                                    N/A
# 1                                                    N/A
# 2                                                    N/A
# 3                                                    N/A
# 4                                                    N/A
# 5                                                    N/A
# 6                                                    N/A
# 7                                                    N/A
# 8      the applicant call on Wednesday, January 12, 2...
# 9                                                    N/A
# ...                                                  ...
# 28768  Customer Wants To Use ePlans,Entry Monument on...
# 28769  Customer Wants To Use ePlans,Entry Monument on...
# 28771  Customer Wants To Use ePlans Interior work onl...
# 28772                                   ADA IMPROVEMENTS
# 28774  *AO APPLICATION* ,NEW TENANT LAYOUT. NO CHANGE...
# 28775  Removing rusted steel beams from under buildin...
# 28776  Customer Wants To Use ePlans  Interior work on...
# 28778  Interior Alterations on FLOORS 3,4,5 &amp;6 - ...
# 28804  Customer Wants To Use ePlans,Sprint to install...
# 28805                                                N/A
#
#                         W_type                          U_code        NewCity  \
# 0                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 1                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 2                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 3                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 4                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 5                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 6                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 7                        ALTER               BUSINESS BUILDING   Gaithersburg
# 8                        ALTER          INSTITUTIONAL BUILDING       Bethesda
# 9                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# ...                        ...                             ...            ...
# 28768                CONSTRUCT  COMMERCIAL MISCELLANEOUS STRUC          Boyds
# 28769                CONSTRUCT  COMMERCIAL MISCELLANEOUS STRUC          Boyds
# 28771                    ALTER               BUSINESS BUILDING  Silver Spring
# 28772                    ALTER               ASSEMBLY BUILDING    Brookeville
# 28774                    ALTER               BUSINESS BUILDING          Olney
# 28775  RESTORE AND / OR REPAIR             MERCANTILE BUILDING      Rockville
# 28776                    ALTER               BUSINESS BUILDING      Rockville
# 28778                    ALTER               BUSINESS BUILDING  Silver Spring
# 28804                      ADD         MISCELLANEOUS STRUCTURE  Silver Spring
# 28805                    ALTER             MERCANTILE BUILDING  Silver Spring
#
#                                                 Address  \
# 0            19850 CENTURY BLVD\nGERMANTOWN, MD 20874\n
# 1             12901 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 2             12903 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 3             12907 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 4             12909 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 5             12925 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 6             12935 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 7         16507 FREDERICK AVE\nGAITHERSBURG, MD 20877\n
# 8          8600 OLD GEORGETOWN RD\nBETHESDA, MD 20817\n
# 9             12955 PINNACLE DR\nGERMANTOWN, MD 20874\n
# ...                                                 ...
# 28768              14239 DOWITCHER WAY\nBOYDS, MD 20841
# 28769              14236 DOWITCHER WAY\nBOYDS, MD 20841
# 28771          11800 TECH RD\nSILVER SPRING, MD 20904\n
# 28772        19300 GEORGIA AVE\nBROOKEVILLE, MD 20833\n
# 28774              3415 OLANDWOOD CT\nOLNEY, MD 20832\n
# 28775          1776 JEFFERSON ST\nROCKVILLE, MD 20852\n
# 28776            5635 FISHERS LN\nROCKVILLE, MD 20852\n
# 28778         1 DISCOVERY PL\nSILVER SPRING, MD 20910\n
# 28804    201 VALLEY BROOK DR\nSILVER SPRING, MD 20904\n
# 28805  14014 CONNECTICUT AVE\nSILVER SPRING, MD 20906\n
#
#                            LL
# 0       39.181866, -77.26558)
# 1      39.182081, -77.265196)
# 2      39.182361, -77.265512)
# 3      39.182922, -77.266143)
# 4      39.183215, -77.266444)
# 5      39.183411, -77.266188)
# 6       39.18353, -77.265984)
# 7       39.127932, -77.18505)
# 8       38.997251, -77.10922)
# 9       39.18377, -77.265575)
# ...                       ...
# 28768                    None
# 28769                    None
# 28771  39.050583, -76.972137)
# 28772  39.176092, -77.058348)
# 28774   39.156018, -77.06703)
# 28775  39.057447, -77.126308)
# 28776  39.062785, -77.114051)
# 28778  38.994829, -77.027997)
# 28804  39.058567, -77.004873)
# 28805  39.085193, -77.074968)
#
# [27633 rows x 20 columns]

# %%
E2 = D2.LL.str.split(",", n =1, expand = True)
# making separate latitude column from new data frame 
D2["Lat"]= E2[0] 
  
# making separate logitude column from new data frame 
D2["Lon"]= E2[1] 

D2["Lat"]= D2.Lat.str.strip('(') 
D2["Lon"]= D2.Lon.str.strip(')')

# %%
D2.LL.isna().value_counts()
# six percent
# Out:
# False    25769
# True      1864
# Name: LL, dtype: int64

# %%
D2.Lon.isna().value_counts()
D2.Lat.isna().value_counts()
# Out:
# False    25769
# True      1864
# Name: Lat, dtype: int64

# %%
#Make some sort of range
D2.Decl_v.value_counts()
# Out:
# 0.00          928
# 25000.00      861
# 20000.00      831
# 10000.00      830
# 15000.00      785
# 50000.00      735
# 100000.00     683
# 30000.00      590
# 200000.00     550
# 5000.00       515
#              ...
# 152569.00       1
# 63600.00        1
# 52478.00        1
# 370670.00       1
# 16163.48        1
# 544708.00       1
# 58620.00        1
# 6979069.00      1
# 4400000.00      1
# 335825.00       1
# Name: Decl_v, Length: 4724, dtype: int64

# %% [markdown]
# Make buckets to put valuation of buildings for example 1000 - 10000, 10000 - 50000, 50000- 100000, 10000
# 0.0	20841.0	20871.0	20902.00	2.177100e+04

# %%
Abins = [ 1.0 , 1000.0, 5000.0, 10000.0, 20000.0, 21000.0, 50000.0, 160000.0 ]
Agroup_names = [ '1sq.ft-1000sq.ft','1000sq.ft-5000sq.ft', '5000sq.ft-10000sq.ft', '10000sq.ft-20000sq.ft',
            '20000sq.ft-21000sq.ft','21000sq.ft-50000sq.ft','50000sq.ft-160000sq.ft' ]

# %%
D2['Area'] = pd.cut(D2['Building_area'], Abins, labels=Agroup_names)
D2['Area'].value_counts()
# Out:
# 1000sq.ft-5000sq.ft       10744
# 1sq.ft-1000sq.ft           7429
# 5000sq.ft-10000sq.ft       2014
# 10000sq.ft-20000sq.ft      1600
# 21000sq.ft-50000sq.ft      1151
# 50000sq.ft-160000sq.ft      853
# 20000sq.ft-21000sq.ft        77
# Name: Area, dtype: int64

# %%
bins = [1000.0,10000.0, 18000.0, 60000.0, 200000.0, 1000000.0, 5000000.0,
10000000.0, 20000000.0, 50000000.0, 100000000.0, 200000000.0]
group_names = [ '1k-10k', '10k-18k', '18k-60k', '60k-200k', '200k-1m',
   '1m-5m', '5m-10m', '10m-20m', '20m-50m', '50m-100M', '100m- 2b' ]

# %%
D2['Value'] = pd.cut(D2['Decl_v'], bins, labels=group_names)
D2['Value'].value_counts()
# there is only one permit with a value of over 1 billion dollars
# Out:
# 60k-200k    7039
# 18k-60k     6828
# 200k-1m     4546
# 1k-10k      3623
# 10k-18k     1729
# 1m-5m       1450
# 5m-10m       268
# 10m-20m      181
# 20m-50m      157
# 50m-100M      42
# 100m- 2b       7
# Name: Value, dtype: int64

# %%
type(cp2.Location[1])
type(cp2.St_num[1])
# Out:
# str

# %%
open_permits = D2.loc[(D2.Status == 'Open')]
open_permits.to_csv('open')

# %%
#filtering by year slices
Y_2000 = D2[(D2['A_date'] > '01/01/2000') & (D2['A_date'] < '01/01/2001')]
Y_2001 = D2[(D2['A_date'] > '01/01/2001') & (D2['A_date'] < '01/01/2002')]
Y_2002 = D2[(D2['A_date'] > '01/01/2002') & (D2['A_date'] < '01/01/2003')]
Y_2003 = D2[(D2['A_date'] > '01/01/2003') & (D2['A_date'] < '01/01/2004')]
Y_2004 = D2[(D2['A_date'] > '01/01/2004') & (D2['A_date'] < '01/01/2005')]
Y_2005 = D2[(D2['A_date'] > '01/01/2005') & (D2['A_date'] < '01/01/2006')]
Y_2006 = D2[(D2['A_date'] > '01/01/2006') & (D2['A_date'] < '01/01/2007')]
Y_2007 = D2[(D2['A_date'] > '01/01/2007') & (D2['A_date'] < '01/01/2008')]
Y_2008 = D2[(D2['A_date'] > '01/01/2008') & (D2['A_date'] < '01/01/2009')]
Y_2009 = D2[(D2['A_date'] > '01/01/2009') & (D2['A_date'] < '01/01/2010')]
Y_2010 = D2[(D2['A_date'] > '01/01/2010') & (D2['A_date'] < '01/01/2011')]
Y_2011 = D2[(D2['A_date'] > '01/01/2011') & (D2['A_date'] < '01/01/2012')]
Y_2012 = D2[(D2['A_date'] > '01/01/2012') & (D2['A_date'] < '01/01/2013')]
Y_2013 = D2[(D2['A_date'] > '01/01/2013') & (D2['A_date'] < '01/01/2014')]
Y_2014 = D2[(D2['A_date'] > '01/01/2014') & (D2['A_date'] < '01/01/2015')]
Y_2015 = D2[(D2['A_date'] > '01/01/2015') & (D2['A_date'] < '01/01/2016')]
Y_2016 = D2[(D2['A_date'] > '01/01/2016') & (D2['A_date'] < '01/01/2017')]
Y_2017 = D2[(D2['A_date'] > '01/01/2017') & (D2['A_date'] < '01/01/2018')]
Y_2018 = D2[(D2['A_date'] > '01/01/2018') & (D2['A_date'] < '01/01/2019')]
Y_2019 = D2[(D2['A_date'] > '01/01/2019') & (D2['A_date'] < '01/01/2020')]
Y_2000
# Out:
#        P_num   Status St_num Pre_d         St_name St_suf Post_d  \
# 0     208677  Finaled  19850   N/A         CENTURY   BLVD    N/A
# 1     208678  Finaled  12901   N/A        PINNACLE     DR    N/A
# 2     208679  Finaled  12903   N/A        PINNACLE     DR    N/A
# 3     208689  Finaled  12907   N/A        PINNACLE     DR    N/A
# 4     208690  Finaled  12909   N/A        PINNACLE     DR    N/A
# 5     208691  Finaled  12925   N/A        PINNACLE     DR    N/A
# 6     208692   Issued  12935   N/A        PINNACLE     DR    N/A
# 7     208716  Finaled  16507     S       FREDERICK    AVE    N/A
# 8     208739  Finaled   8600   N/A  OLD GEORGETOWN     RD    N/A
# 9     208772  Finaled  12955   N/A        PINNACLE     DR    N/A
# ...      ...      ...    ...   ...             ...    ...    ...
# 924   237660   Issued  20001   N/A    CRYSTAL ROCK     DR    N/A
# 925   237661   Issued  20001   N/A    CRYSTAL ROCK     DR    N/A
# 926   237662   Issued  12935   N/A        PINNACLE     DR    N/A
# 927   237664   Issued  12925   N/A        PINNACLE     DR    N/A
# 928   237665   Issued  12909   N/A        PINNACLE     DR    N/A
# 929   237666   Issued  20001   N/A    CRYSTAL ROCK     DR    N/A
# 930   237667   Issued  20001   N/A    CRYSTAL ROCK     DR    N/A
# 931   237668   Issued  19868   N/A         CENTURY   BLVD    N/A
# 932   237669   Issued  19866   N/A         CENTURY   BLVD    N/A
# 1814  255702     Open  11701   N/A        DANVILLE     DR    N/A
#
#               City    Zip     A_date     I_date               F_date  \
# 0       GERMANTOWN  20874 2000-01-03 2000-12-14  2001-10-10 00:00:00
# 1       GERMANTOWN  20874 2000-01-03 2000-12-14  2001-10-11 00:00:00
# 2       GERMANTOWN  20874 2000-01-03 2000-12-14  2001-10-12 00:00:00
# 3       GERMANTOWN  20874 2000-01-03 2000-12-14  2002-01-31 00:00:00
# 4       GERMANTOWN  20874 2000-01-03 2000-12-14  2002-01-29 00:00:00
# 5       GERMANTOWN  20874 2000-01-03 2000-12-14  2002-01-25 00:00:00
# 6       GERMANTOWN  20874 2000-01-03 2000-12-14                  N/A
# 7     GAITHERSBURG  20877 2000-01-03 2000-01-03  2000-01-19 00:00:00
# 8         BETHESDA  20817 2000-01-04 2000-01-27  2000-10-31 00:00:00
# 9       GERMANTOWN  20874 2000-01-04 2000-12-14  2001-12-21 00:00:00
# ...            ...    ...        ...        ...                  ...
# 924     GERMANTOWN  20874 2000-12-29 2001-01-18                  N/A
# 925     GERMANTOWN  20874 2000-12-29 2001-01-18                  N/A
# 926     GERMANTOWN  20874 2000-12-29 2001-01-18                  N/A
# 927     GERMANTOWN  20874 2000-12-29 2001-01-18                  N/A
# 928     GERMANTOWN  20874 2000-12-29 2001-01-18                  N/A
# 929     GERMANTOWN  20874 2000-12-29 2001-01-18                  N/A
# 930     GERMANTOWN  20874 2000-12-29 2001-01-18                  N/A
# 931     GERMANTOWN  20874 2000-12-29 2001-01-18                  N/A
# 932     GERMANTOWN  20874 2000-12-29 2001-01-18                  N/A
# 1814     ROCKVILLE  20852 2000-11-30        NaT                  N/A
#
#       Building_area     Decl_v  \
# 0           42600.0  1000000.0
# 1           42600.0  1000000.0
# 2           42600.0  1000000.0
# 3           63300.0  1500000.0
# 4           63300.0  1500000.0
# 5           63300.0  1500000.0
# 6           63300.0  1500000.0
# 7            3000.0    10000.0
# 8           10350.0   110000.0
# 9           36400.0   750000.0
# ...             ...        ...
# 924         36400.0        1.0
# 925         36400.0        1.0
# 926         63300.0        1.0
# 927         63300.0        1.0
# 928         63300.0        1.0
# 929         15600.0        1.0
# 930         36400.0        1.0
# 931         15600.0        1.0
# 932         15600.0        1.0
# 1814          126.0    10000.0
#
#                                                    Desc     W_type  \
# 0                                                   N/A  CONSTRUCT
# 1                                                   N/A  CONSTRUCT
# 2                                                   N/A  CONSTRUCT
# 3                                                   N/A  CONSTRUCT
# 4                                                   N/A  CONSTRUCT
# 5                                                   N/A  CONSTRUCT
# 6                                                   N/A  CONSTRUCT
# 7                                                   N/A      ALTER
# 8     the applicant call on Wednesday, January 12, 2...      ALTER
# 9                                                   N/A  CONSTRUCT
# ...                                                 ...        ...
# 924                              REVISION TO FOUNDATION      ALTER
# 925                              REVISION TO FOUNDATION      ALTER
# 926                              REVISION TO FOUNDATION      ALTER
# 927                              REVISION TO FOUNDATION      ALTER
# 928                              REVISION TO FOUNDATION      ALTER
# 929                              REVISION TO FOUNDATION      ALTER
# 930                              REVISION TO FOUNDATION      ALTER
# 931                              REVISION TO FOUNDATION      ALTER
# 932                              REVISION TO FOUNDATION      ALTER
# 1814                                     RETAINING WALL  CONSTRUCT
#
#                       U_code       NewCity  \
# 0      MULTI-FAMILY DWELLING    Germantown
# 1      MULTI-FAMILY DWELLING    Germantown
# 2      MULTI-FAMILY DWELLING    Germantown
# 3      MULTI-FAMILY DWELLING    Germantown
# 4      MULTI-FAMILY DWELLING    Germantown
# 5      MULTI-FAMILY DWELLING    Germantown
# 6      MULTI-FAMILY DWELLING    Germantown
# 7          BUSINESS BUILDING  Gaithersburg
# 8     INSTITUTIONAL BUILDING      Bethesda
# 9      MULTI-FAMILY DWELLING    Germantown
# ...                      ...           ...
# 924    MULTI-FAMILY DWELLING    Germantown
# 925    MULTI-FAMILY DWELLING    Germantown
# 926    MULTI-FAMILY DWELLING    Germantown
# 927    MULTI-FAMILY DWELLING    Germantown
# 928    MULTI-FAMILY DWELLING    Germantown
# 929    MULTI-FAMILY DWELLING    Germantown
# 930    MULTI-FAMILY DWELLING    Germantown
# 931    MULTI-FAMILY DWELLING    Germantown
# 932    MULTI-FAMILY DWELLING    Germantown
# 1814          RETAINING WALL     Rockville
#
#                                             Address                      LL  \
# 0        19850 CENTURY BLVD\nGERMANTOWN, MD 20874\n   39.181866, -77.26558)
# 1         12901 PINNACLE DR\nGERMANTOWN, MD 20874\n  39.182081, -77.265196)
# 2         12903 PINNACLE DR\nGERMANTOWN, MD 20874\n  39.182361, -77.265512)
# 3         12907 PINNACLE DR\nGERMANTOWN, MD 20874\n  39.182922, -77.266143)
# 4         12909 PINNACLE DR\nGERMANTOWN, MD 20874\n  39.183215, -77.266444)
# 5         12925 PINNACLE DR\nGERMANTOWN, MD 20874\n  39.183411, -77.266188)
# 6         12935 PINNACLE DR\nGERMANTOWN, MD 20874\n   39.18353, -77.265984)
# 7     16507 FREDERICK AVE\nGAITHERSBURG, MD 20877\n   39.127932, -77.18505)
# 8      8600 OLD GEORGETOWN RD\nBETHESDA, MD 20817\n   38.997251, -77.10922)
# 9         12955 PINNACLE DR\nGERMANTOWN, MD 20874\n   39.18377, -77.265575)
# ...                                             ...                     ...
# 924     20001 CRYSTAL ROCK DR\nGERMANTOWN, MD 20874                    None
# 925     20001 CRYSTAL ROCK DR\nGERMANTOWN, MD 20874                    None
# 926       12935 PINNACLE DR\nGERMANTOWN, MD 20874\n   39.18353, -77.265984)
# 927       12925 PINNACLE DR\nGERMANTOWN, MD 20874\n  39.183411, -77.266188)
# 928       12909 PINNACLE DR\nGERMANTOWN, MD 20874\n  39.183215, -77.266444)
# 929     20001 CRYSTAL ROCK DR\nGERMANTOWN, MD 20874                    None
# 930     20001 CRYSTAL ROCK DR\nGERMANTOWN, MD 20874                    None
# 931      19868 CENTURY BLVD\nGERMANTOWN, MD 20874\n  39.181544, -77.266156)
# 932      19866 CENTURY BLVD\nGERMANTOWN, MD 20874\n   39.18158, -77.266092)
# 1814       11701 DANVILLE DR\nROCKVILLE, MD 20852\n  39.048891, -77.132726)
#
#             Lat          Lon                    Area     Value
# 0     39.181866    -77.26558   21000sq.ft-50000sq.ft   200k-1m
# 1     39.182081   -77.265196   21000sq.ft-50000sq.ft   200k-1m
# 2     39.182361   -77.265512   21000sq.ft-50000sq.ft   200k-1m
# 3     39.182922   -77.266143  50000sq.ft-160000sq.ft     1m-5m
# 4     39.183215   -77.266444  50000sq.ft-160000sq.ft     1m-5m
# 5     39.183411   -77.266188  50000sq.ft-160000sq.ft     1m-5m
# 6      39.18353   -77.265984  50000sq.ft-160000sq.ft     1m-5m
# 7     39.127932    -77.18505     1000sq.ft-5000sq.ft    1k-10k
# 8     38.997251    -77.10922   10000sq.ft-20000sq.ft  60k-200k
# 9      39.18377   -77.265575   21000sq.ft-50000sq.ft   200k-1m
# ...         ...          ...                     ...       ...
# 924        None         None   21000sq.ft-50000sq.ft       NaN
# 925        None         None   21000sq.ft-50000sq.ft       NaN
# 926    39.18353   -77.265984  50000sq.ft-160000sq.ft       NaN
# 927   39.183411   -77.266188  50000sq.ft-160000sq.ft       NaN
# 928   39.183215   -77.266444  50000sq.ft-160000sq.ft       NaN
# 929        None         None   10000sq.ft-20000sq.ft       NaN
# 930        None         None   21000sq.ft-50000sq.ft       NaN
# 931   39.181544   -77.266156   10000sq.ft-20000sq.ft       NaN
# 932    39.18158   -77.266092   10000sq.ft-20000sq.ft       NaN
# 1814  39.048891   -77.132726        1sq.ft-1000sq.ft    1k-10k
#
# [926 rows x 24 columns]

# %% [markdown]
# #see how much data was in each year:Na
#                                     non-Na

# %% [markdown]
# # Exploration

# %% [markdown]
# Ideas I want to do.
# 1. Show how many permits are the same address: seeing how are unique vs non unique
# 2. Seeing which categories have the most value
# 3. Look at construction more in depth: what type of construction; frequency; also over the years
# 4. look at open permits
# 5. Grouping permits by their description: so I would potentially combine the use code and description to see what type
# 6. See if an area is growing faster than another area

# %%
D2.U_code.value_counts(normalize=True)
# Out:
# BUSINESS BUILDING                 0.250642
# MULTI-FAMILY DWELLING             0.165418
# COMMERCIAL MISCELLANEOUS STRUC    0.102776
# MERCANTILE BUILDING               0.081605
# TOWNHOUSE                         0.061086
# RESTAURANT                        0.055839
# EDUCATIONAL BUILDING              0.052112
# ASSEMBLY BUILDING                 0.038288
# STORAGE BUILDING                  0.022111
# MULTIFAMILY DWELLING LOW RISE     0.020881
#                                     ...
# SINGLE FAMILY DWELLING            0.000072
# ASSEMBLY, NIGHTCLUBS              0.000072
# INSTITUTIONAL, SUPV ENVIRONMNT    0.000036
# HIGH HAZARD                       0.000036
# CHARITABLE  PHILANTHROPIC         0.000036
# DUMPSTER                          0.000036
# ASSEMBLY, THEATERS, W/STAGE       0.000036
# RESIDENTIAL, MULTIPLE FAMILY      0.000036
# POOL - ABOVE GROUND               0.000036
# ASSEMBLY, RESTAURANTS, BARS       0.000036
# Name: U_code, Length: 67, dtype: float64

# %%
D2['W_type'].value_counts(normalize=True)
# Out:
# ALTER                         0.540224
# CONSTRUCT                     0.275938
# ADD                           0.090291
# RESTORE AND / OR REPAIR       0.052618
# COMMERCIAL CHANGE OF USE      0.024174
# BUILD FOUNDATION              0.006984
# CONSTRUCT SHEETING/SHORING    0.004487
# INSTALL                       0.002642
# REMOVE AND REPLACE            0.001701
# REPLACE                       0.000470
# FINAL ONLY AP                 0.000253
# OCCUPY                        0.000109
# DEMOLISH                      0.000109
# Name: W_type, dtype: float64

# %%
rv = D2['Address'].value_counts()
rv.head(4193)
#4193 address have two permits attached to address that have same value
# Out:
# 7101 DEMOCRACY BLVD\nBETHESDA, MD 20817\n             264
# 11160 VEIRS MILL RD\nSILVER SPRING, MD 20902\n        199
# 8500 RIVER RD\nBETHESDA, MD 20817\n                   133
# 22705 CLARKSBURG RD\nBOYDS, MD 20841\n                119
# 1500 FOREST GLEN RD\nSILVER SPRING, MD 20910\n         91
# 8600 OLD GEORGETOWN RD\nBETHESDA, MD 20817\n           88
# 9901 MEDICAL CENTER DR\nROCKVILLE, MD 20850\n          74
# 7315 WISCONSIN AVE\nCHEVY CHASE, MD 20815              68
# 5454 WISCONSIN AVE\nCHEVY CHASE, MD 20815\n            65
# 8661 COLESVILLE RD\nSILVER SPRING, MD 20910\n          64
#                                                      ...
# 2900 UNIVERSITY BLVD W\nSILVER SPRING, MD 20902\n       2
# 7802 PEARSON KNOLL PL\nPOTOMAC, MD 20854\n              2
# 23630 WOODFIELD RD\nGAITHERSBURG, MD 20882\n            2
# 9230 GAITHER RD\nGAITHERSBURG, MD 20877\n               2
# 5315 ELLIOTT RD\nBETHESDA, MD 20816\n                   2
# 12201 NEW HAMPSHIRE AVE\nSILVER SPRING, MD 20904\n      2
# 12101 SNOWDEN FARM PKWY\nCLARKSBURG, MD 20871\n         2
# 18221 VILLAGE CENTER DR\nOLNEY, MD 20832\n              2
# 9723 TRAVILLE GATEWAY DR\nROCKVILLE, MD 20850\n         2
# 1131 UNIVERSITY BLVD W\nSILVER SPRING, MD 20902\n       2
# Name: Address, Length: 4193, dtype: int64

# %%
#Seeing the Address which have the most permits
Ad = D2.Address.value_counts()
Ad.head(11).sum()
Ad.head(11)
# 1225 Permits so about 4.5 Percent of total permits
# Out:
# 7101 DEMOCRACY BLVD\nBETHESDA, MD 20817\n         264
# 11160 VEIRS MILL RD\nSILVER SPRING, MD 20902\n    199
# 8500 RIVER RD\nBETHESDA, MD 20817\n               133
# 22705 CLARKSBURG RD\nBOYDS, MD 20841\n            119
# 1500 FOREST GLEN RD\nSILVER SPRING, MD 20910\n     91
# 8600 OLD GEORGETOWN RD\nBETHESDA, MD 20817\n       88
# 9901 MEDICAL CENTER DR\nROCKVILLE, MD 20850\n      74
# 7315 WISCONSIN AVE\nCHEVY CHASE, MD 20815          68
# 5454 WISCONSIN AVE\nCHEVY CHASE, MD 20815\n        65
# 8661 COLESVILLE RD\nSILVER SPRING, MD 20910\n      64
# 9800 MEDICAL CENTER DR\nROCKVILLE, MD 20850\n      60
# Name: Address, dtype: int64

# %% [markdown]
# 1. 7101 DEMOCRACY BLVD BETHESDA, MD 20817 = Westfield Montgomery (Mall)
# 2. 11160 VEIRS MILL RD SILVER SPRING, MD 20902 = Westfield Wheaton (Mall)
# 3. 8500 RIVER RD BETHESDA, MD 20817 = Congressional Country Club
# 4. 22705 CLARKSBURG RD BOYDS, MD 20841 = Clarksburg Premium Outlets
# 5. 1500 FOREST GLEN RD SILVER SPRING, MD 20910 = Holy Cross Hospital
# 6. 8600 OLD GEORGETOWN RD BETHESDA, MD 20817 = John Hopkins Suburban Hospital
# 7. 9901 MEDICAL CENTER DR ROCKVILLE, MD 20850 = Adventist Healthcare Center
# 8. 7315 WISCONSIN AVE CHEVY CHASE, MD 20815 = Johns Hopkins Bethesda
# 9. 5454 Wisconsin Ave, Chevy Chase, MD 20815 = Barlow Building; MedStar Health
# 10. 8661 COLESVILLE RD SILVER SPRING, MD 20910 = Ellsworth Place (Mall)
# 11. 9800 MEDICAL CENTER DR ROCKVILLE, MD 20850 = Adventist Medical Center

# %% [markdown]
# I want to see how many of the permits are on the same address
# Then calculate the percentage of unique permits out of total number of permits
# Would Look like: 564 non unique
#                 14573 unique

# %%
D2[D2.Desc.str.contains("permit")]
#group thing by going throught thier discrip
# Out:
#         P_num   Status St_num Pre_d             St_name St_suf Post_d  \
# 8      208739  Finaled   8600   N/A      OLD GEORGETOWN     RD    N/A
# 19     209053  Finaled   9910   N/A      BELWARD CAMPUS     DR    N/A
# 48     209989  Finaled   7420   N/A            WESTLAKE    TER    N/A
# 53     210170   Issued  12530   N/A            PARKLAWN     DR    N/A
# 126    211626  Finaled  10720   N/A            COLUMBIA   PIKE    N/A
# 127    211628  Finaled   1140   N/A           EAST WEST    HWY    N/A
# 256    216263   Issued   5335   N/A            WESTBARD    AVE    N/A
# 392    220362   Issued  11717   N/A         EXPLORATION     LN    N/A
# 464    222841   Issued  11501   N/A            COLUMBIA   PIKE    N/A
# 590    227688  Finaled    676   N/A             HOUSTON    AVE    N/A
# ...       ...      ...    ...   ...                 ...    ...    ...
# 28378  886849     Open  12835   N/A             LOCBURY    CIR    N/A
# 28379  886850     Open  12837   N/A             LOCBURY    CIR    N/A
# 28380  886851     Open  12841   N/A             LOCBURY    CIR    N/A
# 28381  886852     Open  12843   N/A             LOCBURY    CIR    N/A
# 28382  886853     Open  12845   N/A             LOCBURY    CIR    N/A
# 28484  888609     Open  12701   N/A            GOODHILL     RD    N/A
# 28582  890378     Open  19134   N/A  MONTGOMERY VILLAGE    AVE    N/A
# 28621  891210     Open  12835   N/A           FAIRCHILD     DR    N/A
# 28642  891636     Open  20326   N/A      SENECA MEADOWS   PKWY    N/A
# 28644  891734     Open  20314   N/A      SENECA MEADOWS   PKWY    N/A
#
#                      City    Zip     A_date     I_date               F_date  \
# 8                BETHESDA  20817 2000-01-04 2000-01-27  2000-10-31 00:00:00
# 19              ROCKVILLE  20850 2000-01-06 2000-02-02  2000-10-05 00:00:00
# 48               BETHESDA  20817 2000-01-20 2000-01-20  2000-02-09 00:00:00
# 53              ROCKVILLE  20852 2000-01-24 2000-02-11                  N/A
# 126         SILVER SPRING  20901 2000-02-16 2000-03-17  2001-06-21 00:00:00
# 127         SILVER SPRING  20910 2000-02-16 2000-03-10  2000-10-31 00:00:00
# 256              BETHESDA  20816 2000-04-12 2000-06-05                  N/A
# 392            GERMANTOWN  20876 2000-06-01 2000-07-20                  N/A
# 464         SILVER SPRING  20904 2000-06-29 2001-08-06                  N/A
# 590           TAKOMA PARK  20912 2000-08-28 2000-10-11  2004-01-02 00:00:00
# ...                   ...    ...        ...        ...                  ...
# 28378          GERMANTOWN  20874 2019-08-19        NaT                  N/A
# 28379          GERMANTOWN  20874 2019-08-19        NaT                  N/A
# 28380          GERMANTOWN  20874 2019-08-19        NaT                  N/A
# 28381          GERMANTOWN  20874 2019-08-19        NaT                  N/A
# 28382          GERMANTOWN  20874 2019-08-19        NaT                  N/A
# 28484       SILVER SPRING  20906 2019-09-04        NaT                  N/A
# 28582  MONTGOMERY VILLAGE  20886 2019-09-20        NaT                  N/A
# 28621          GERMANTOWN  20874 2019-09-27        NaT                  N/A
# 28642          GERMANTOWN  20876 2019-10-02        NaT                  N/A
# 28644          GERMANTOWN  20876 2019-10-03        NaT                  N/A
#
#        Building_area       Decl_v  \
# 8            10350.0    110000.00
# 19           43689.0  10366000.00
# 48             240.0        50.00
# 53           83500.0    250000.00
# 126            640.0     10000.00
# 127         116756.0   4540000.00
# 256         148628.0   2500000.00
# 392          17630.0         0.00
# 464           3400.0    375000.00
# 590          38130.0    610000.00
# ...              ...          ...
# 28378           69.0      2297.06
# 28379           69.0      2297.06
# 28380           69.0      2297.06
# 28381           69.0      2297.06
# 28382           69.0      2297.06
# 28484         5896.0    800000.00
# 28582         2891.0    600000.00
# 28621           28.0      4000.00
# 28642         9929.0    377000.00
# 28644          368.0       100.00
#
#                                                     Desc  \
# 8      the applicant call on Wednesday, January 12, 2...
# 19                 revisions to permit number 9908040072
# 48                  revision to permit number 998100069.
# 53                   revision to permit number 983260085
# 126    adding 2 canopies\npermit extended 6 months fr...
# 127    Green Tape   Interior tenant buildout (Compute...
# 256    REVISION TO A/P#209085 - the original permit w...
# 392    This permit is for the construction of the fou...
# 464    If this company calls for an inspection - give...
# 590        all interior, and canopy permit number 229195
# ...                                                  ...
# 28378  STAIR REPAIR - 36 total permits - all permits ...
# 28379  STAIR REPAIR - 36 total permits - all permits ...
# 28380  STAIR REPAIR - 36 total permits - all permits ...
# 28381  STAIR REPAIR - 36 total permits - all permits ...
# 28382  STAIR REPAIR - 36 total permits - all permits ...
# 28484  Customer Wants To Use ePlans Interior work onl...
# 28582  Customer Wants To Use ePlans,New bank interior...
# 28621  Customer Wants To Use ePlans,This permit is fo...
# 28642  Customer Wants To Use ePlans,***2 permits on o...
# 28644  Customer Wants To Use ePlans***2 permits on on...
#
#                         W_type                          U_code  \
# 8                        ALTER          INSTITUTIONAL BUILDING
# 19                       ALTER               BUSINESS BUILDING
# 48                       ALTER  COMMERCIAL MISCELLANEOUS STRUC
# 53                       ALTER               BUSINESS BUILDING
# 126                        ADD               BUSINESS BUILDING
# 127                      ALTER               BUSINESS BUILDING
# 256                  CONSTRUCT                STORAGE BUILDING
# 392                        ADD               BUSINESS BUILDING
# 464                        ADD             INDUSTRIAL BUILDING
# 590                      ALTER           MULTI-FAMILY DWELLING
# ...                        ...                             ...
# 28378  RESTORE AND / OR REPAIR   MULTIFAMILY DWELLING LOW RISE
# 28379  RESTORE AND / OR REPAIR   MULTIFAMILY DWELLING LOW RISE
# 28380  RESTORE AND / OR REPAIR   MULTIFAMILY DWELLING LOW RISE
# 28381  RESTORE AND / OR REPAIR   MULTIFAMILY DWELLING LOW RISE
# 28382  RESTORE AND / OR REPAIR   MULTIFAMILY DWELLING LOW RISE
# 28484                    ALTER            EDUCATIONAL BUILDING
# 28582                    ALTER                            BANK
# 28621                CONSTRUCT  COMMERCIAL MISCELLANEOUS STRUC
# 28642                    ALTER               BUSINESS BUILDING
# 28644                    ALTER               BUSINESS BUILDING
#
#                   NewCity                                            Address  \
# 8                Bethesda       8600 OLD GEORGETOWN RD\nBETHESDA, MD 20817\n
# 19              Rockville      9910 BELWARD CAMPUS DR\nROCKVILLE, MD 20850\n
# 48               Bethesda            7420 WESTLAKE TER\nBETHESDA, MD 20817\n
# 53              Rockville           12530 PARKLAWN DR\nROCKVILLE, MD 20852\n
# 126         Silver Spring     10720 COLUMBIA PIKE\nSILVER SPRING, MD 20901\n
# 127         Silver Spring      1140 EAST WEST HWY\nSILVER SPRING, MD 20910\n
# 256              Bethesda            5335 WESTBARD AVE\nBETHESDA, MD 20816\n
# 392            Germantown       11717 EXPLORATION LN\nGERMANTOWN, MD 20876\n
# 464         Silver Spring     11501 COLUMBIA PIKE\nSILVER SPRING, MD 20904\n
# 590           Takoma Park           676 HOUSTON AVE\nTAKOMA PARK, MD 20912\n
# ...                   ...                                                ...
# 28378          Germantown          12835 LOCBURY CIR\nGERMANTOWN, MD 20874\n
# 28379          Germantown          12837 LOCBURY CIR\nGERMANTOWN, MD 20874\n
# 28380          Germantown          12841 LOCBURY CIR\nGERMANTOWN, MD 20874\n
# 28381          Germantown          12843 LOCBURY CIR\nGERMANTOWN, MD 20874\n
# 28382          Germantown          12845 LOCBURY CIR\nGERMANTOWN, MD 20874\n
# 28484       Silver Spring       12701 GOODHILL RD\nSILVER SPRING, MD 20906\n
# 28582  Montgomery Village  19134 MONTGOMERY VILLAGE AVE\nMONTGOMERY VILLA...
# 28621          Germantown           12835 FAIRCHILD DR\nGERMANTOWN, MD 20874
# 28642          Germantown  20326 SENECA MEADOWS PKWY\nGERMANTOWN, MD 20876\n
# 28644          Germantown  20314 SENECA MEADOWS PKWY\nGERMANTOWN, MD 20876\n
#
#                            LL        Lat          Lon                    Area  \
# 8       38.997251, -77.10922)  38.997251    -77.10922   10000sq.ft-20000sq.ft
# 19     39.103986, -77.209925)  39.103986   -77.209925   21000sq.ft-50000sq.ft
# 48     39.026817, -77.150874)  39.026817   -77.150874        1sq.ft-1000sq.ft
# 53     39.061603, -77.117877)  39.061603   -77.117877  50000sq.ft-160000sq.ft
# 126    39.031445, -77.004657)  39.031445   -77.004657        1sq.ft-1000sq.ft
# 127    38.989165, -77.028217)  38.989165   -77.028217  50000sq.ft-160000sq.ft
# 256    38.962661, -77.106335)  38.962661   -77.106335  50000sq.ft-160000sq.ft
# 392     39.178503, -77.24404)  39.178503    -77.24404   10000sq.ft-20000sq.ft
# 464     39.045968, -76.98768)  39.045968    -76.98768     1000sq.ft-5000sq.ft
# 590     38.99069, -77.003861)   38.99069   -77.003861   21000sq.ft-50000sq.ft
# ...                       ...        ...          ...                     ...
# 28378  39.186282, -77.264363)  39.186282   -77.264363        1sq.ft-1000sq.ft
# 28379   39.18627, -77.264486)   39.18627   -77.264486        1sq.ft-1000sq.ft
# 28380  39.186257, -77.264609)  39.186257   -77.264609        1sq.ft-1000sq.ft
# 28381  39.186259, -77.264654)  39.186259   -77.264654        1sq.ft-1000sq.ft
# 28382     39.18626, -77.2647)   39.18626     -77.2647        1sq.ft-1000sq.ft
# 28484   39.064588, -77.07204)  39.064588    -77.07204    5000sq.ft-10000sq.ft
# 28582  39.170658, -77.204158)  39.170658   -77.204158     1000sq.ft-5000sq.ft
# 28621                    None       None         None        1sq.ft-1000sq.ft
# 28642  39.189608, -77.253812)  39.189608   -77.253812    5000sq.ft-10000sq.ft
# 28644  39.189202, -77.252649)  39.189202   -77.252649        1sq.ft-1000sq.ft
#
#           Value
# 8      60k-200k
# 19      10m-20m
# 48          NaN
# 53      200k-1m
# 126      1k-10k
# 127       1m-5m
# 256       1m-5m
# 392         NaN
# 464     200k-1m
# 590     200k-1m
# ...         ...
# 28378    1k-10k
# 28379    1k-10k
# 28380    1k-10k
# 28381    1k-10k
# 28382    1k-10k
# 28484   200k-1m
# 28582   200k-1m
# 28621    1k-10k
# 28642   200k-1m
# 28644       NaN
#
# [901 rows x 24 columns]

# %%
D2['Value'].value_counts(ascending=False).plot.barh();

# %%
D2['Area'].value_counts(ascending=False).plot.barh();

# %% [markdown]
# Investigate Construction See if there is a change in the types of buildings bieng constructed
# See the frequency of a specofoc area

# %%
D2['W_type'].value_counts().plot.barh();

# %% [markdown]
# Sorting and filtering the type of work in a permit to see what the values are

# %%
D6 = D2.loc[(D2.W_type == 'ALTER' )]
D7 = D2.loc[(D2.W_type == 'CONSTRUCT' )]
D8 = D2.loc[(D2.W_type == 'ADD' )]
D9 = D2.loc[(D2.W_type == 'RESTORE AND / OR REPAIR' )]
D10 = D2.loc[(D2.W_type == 'COMMERCIAL CHANGE OF USE' )]

# %%
display(D6.Decl_v.sum())
display(D7.Decl_v.sum())
display(D8.Decl_v.sum())
display(D9.Decl_v.sum())
display(D10.Decl_v.sum())
# Out:
# 4501448981.35
# 12385695553.619999
# 3232686683.51
# 259411233.79000002
# 88375911.4

# %%
D6.U_code.value_counts(ascending=False).sum()
# Out:
# 14928

# %% [markdown]
# “ePlans” is a web-based application that facilitates electronic plan submission and review that
# has been tailored to meet the Montgomery County Department of Permitting Services’ (DPS)
# processes using ProjectDox software. ePlans allows drawings and documents to be submitted
# and reviewed electronically, improves the plan review cycle, and reduces costs associated with
# obtaining permits as well as supporting green initiatives

# %%
T1 = D2.loc[(D2.Desc.str.contains("ePlans", case=False))]
T1
# so 3375 rows
# Out:
#         P_num   Status St_num Pre_d        St_name St_suf Post_d  \
# 19534  695623     Open   7101   N/A      DEMOCRACY   BLVD    N/A
# 19535  695624     Open   7101   N/A      DEMOCRACY   BLVD    N/A
# 19536  695625     Open   7101   N/A      DEMOCRACY   BLVD    N/A
# 19537  695626     Open   7101   N/A      DEMOCRACY   BLVD    N/A
# 19551  695706  Finaled  16624   N/A  CRABBS BRANCH    WAY    N/A
# 19611  695850     Open   7101   N/A      DEMOCRACY   BLVD    N/A
# 19612  695851     Open   7101   N/A      DEMOCRACY   BLVD    N/A
# 19613  695852     Open   7101   N/A      DEMOCRACY   BLVD    N/A
# 19707  698505  Finaled   8930   N/A     BROOKVILLE     RD    N/A
# 19775  700967  Finaled  19300   N/A     GERMANTOWN     RD    N/A
# ...       ...      ...    ...   ...            ...    ...    ...
# 28755  893736     Open    137   N/A           KLEE    ALY    N/A
# 28757  893768     Open   8821   N/A          RIVER     RD    N/A
# 28758  893792     Open   9504   N/A        BRUNETT    AVE    N/A
# 28763  893940     Open   9920   N/A       KEY WEST    AVE    N/A
# 28766  894016     Open  15813   N/A      FREDERICK     RD    N/A
# 28768  894100     Open  14239   N/A      DOWITCHER    WAY    N/A
# 28769  894102     Open  14236   N/A      DOWITCHER    WAY    N/A
# 28771  894147     Open  11800   N/A           TECH     RD    N/A
# 28776  894352     Open   5635   N/A        FISHERS     LN    N/A
# 28804  894600     Open    201   N/A   VALLEY BROOK     DR    N/A
#
#                 City    Zip     A_date     I_date               F_date  \
# 19534       BETHESDA  20817 2014-11-24        NaT                  N/A
# 19535       BETHESDA  20817 2014-11-24        NaT                  N/A
# 19536       BETHESDA  20817 2014-11-24        NaT                  N/A
# 19537       BETHESDA  20817 2014-11-24        NaT                  N/A
# 19551      ROCKVILLE  20855 2014-11-24 2014-12-29  2015-09-09 00:00:00
# 19611       BETHESDA  20817 2014-11-25        NaT                  N/A
# 19612       BETHESDA  20817 2014-11-25        NaT                  N/A
# 19613       BETHESDA  20817 2014-11-25        NaT                  N/A
# 19707  SILVER SPRING  20910 2014-12-22 2015-02-03  2015-03-10 00:00:00
# 19775     GERMANTOWN  20874 2015-01-16 2015-03-17  2015-05-19 00:00:00
# ...              ...    ...        ...        ...                  ...
# 28755  SILVER SPRING  20906 2019-10-21        NaT                  N/A
# 28757       BETHESDA  20817 2019-10-21        NaT                  N/A
# 28758  SILVER SPRING  20901 2019-10-22        NaT                  N/A
# 28763      ROCKVILLE  20850 2019-10-23        NaT                  N/A
# 28766      ROCKVILLE  20855 2019-10-23        NaT                  N/A
# 28768          BOYDS  20841 2019-10-24        NaT                  N/A
# 28769          BOYDS  20841 2019-10-24        NaT                  N/A
# 28771  SILVER SPRING  20904 2019-10-24        NaT                  N/A
# 28776      ROCKVILLE  20852 2019-10-25        NaT                  N/A
# 28804  SILVER SPRING  20904 2019-10-28        NaT                  N/A
#
#        Building_area    Decl_v  \
# 19534         1500.0   50000.0
# 19535         1500.0   50000.0
# 19536         1500.0   50000.0
# 19537         1500.0   50000.0
# 19551          500.0   50000.0
# 19611         5000.0   50000.0
# 19612         5000.0   50000.0
# 19613         5000.0   50000.0
# 19707            0.0    5000.0
# 19775         8619.0  350000.0
# ...              ...       ...
# 28755         3522.0  169018.0
# 28757          330.0  100000.0
# 28758            0.0       0.0
# 28763          465.0   55000.0
# 28766         3350.0  190000.0
# 28768          810.0  156854.0
# 28769          800.0  156854.0
# 28771        61257.0  742000.0
# 28776        28510.0  210000.0
# 28804          625.0   39500.0
#
#                                                     Desc  \
# 19534                                ePlans test permits
# 19535                                ePlans test permits
# 19536                                ePlans test permits
# 19537                                ePlans test permits
# 19551  Installation of three (3) outside CNG fueling ...
# 19611                                 ePlans Test Permit
# 19612                                 ePlans Test Permit
# 19613                                 ePlans Test Permit
# 19707  New Tenant Alteration in existing space &amp; ...
# 19775  Interior alteration to Level 1S&nbsp; - Office...
# ...                                                  ...
# 28755  Customer Wants To Use ePlans,Glenmont Metrocen...
# 28757  Customer Wants To Use ePlans,Minor renovation ...
# 28758  Customer Wants To Use ePlans,New Use & Occupan...
# 28763  Customer Wants To Use ePlans,New walk-up ATM w...
# 28766  Customer Wants To Use ePlans,Demolition of exi...
# 28768  Customer Wants To Use ePlans,Entry Monument on...
# 28769  Customer Wants To Use ePlans,Entry Monument on...
# 28771  Customer Wants To Use ePlans Interior work onl...
# 28776  Customer Wants To Use ePlans  Interior work on...
# 28804  Customer Wants To Use ePlans,Sprint to install...
#
#                          W_type                          U_code  \
# 19534                       ADD               BUSINESS BUILDING
# 19535                       ADD               BUSINESS BUILDING
# 19536                       ADD               BUSINESS BUILDING
# 19537                       ADD               BUSINESS BUILDING
# 19551                 CONSTRUCT  COMMERCIAL MISCELLANEOUS STRUC
# 19611                     ALTER               BUSINESS BUILDING
# 19612                     ALTER               BUSINESS BUILDING
# 19613                     ALTER               BUSINESS BUILDING
# 19707                     ALTER               BUSINESS BUILDING
# 19775                     ALTER                      BIOSCIENCE
# ...                         ...                             ...
# 28755                 CONSTRUCT                       TOWNHOUSE
# 28757                     ALTER            EDUCATIONAL BUILDING
# 28758  COMMERCIAL CHANGE OF USE            EDUCATIONAL BUILDING
# 28763                       ADD             MERCANTILE BUILDING
# 28766                     ALTER             MERCANTILE BUILDING
# 28768                 CONSTRUCT  COMMERCIAL MISCELLANEOUS STRUC
# 28769                 CONSTRUCT  COMMERCIAL MISCELLANEOUS STRUC
# 28771                     ALTER               BUSINESS BUILDING
# 28776                     ALTER               BUSINESS BUILDING
# 28804                       ADD         MISCELLANEOUS STRUCTURE
#
#              NewCity                                         Address  \
# 19534       Bethesda       7101 DEMOCRACY BLVD\nBETHESDA, MD 20817\n
# 19535       Bethesda       7101 DEMOCRACY BLVD\nBETHESDA, MD 20817\n
# 19536       Bethesda       7101 DEMOCRACY BLVD\nBETHESDA, MD 20817\n
# 19537       Bethesda       7101 DEMOCRACY BLVD\nBETHESDA, MD 20817\n
# 19551        Derwood  16624 CRABBS BRANCH WAY\nROCKVILLE, MD 20855\n
# 19611       Bethesda       7101 DEMOCRACY BLVD\nBETHESDA, MD 20817\n
# 19612       Bethesda       7101 DEMOCRACY BLVD\nBETHESDA, MD 20817\n
# 19613       Bethesda       7101 DEMOCRACY BLVD\nBETHESDA, MD 20817\n
# 19707  Silver Spring   8930 BROOKVILLE RD\nSILVER SPRING, MD 20910\n
# 19775     Germantown     19300 GERMANTOWN RD\nGERMANTOWN, MD 20874\n
# ...              ...                                             ...
# 28755  Silver Spring           137 KLEE ALY\nSILVER SPRING, MD 20906
# 28757       Bethesda             8821 RIVER RD\nBETHESDA, MD 20817\n
# 28758  Silver Spring     9504 BRUNETT AVE\nSILVER SPRING, MD 20901\n
# 28763      Rockville        9920 KEY WEST AVE\nROCKVILLE, MD 20850\n
# 28766        Derwood       15813 FREDERICK RD\nROCKVILLE, MD 20855\n
# 28768          Boyds            14239 DOWITCHER WAY\nBOYDS, MD 20841
# 28769          Boyds            14236 DOWITCHER WAY\nBOYDS, MD 20841
# 28771  Silver Spring        11800 TECH RD\nSILVER SPRING, MD 20904\n
# 28776      Rockville          5635 FISHERS LN\nROCKVILLE, MD 20852\n
# 28804  Silver Spring  201 VALLEY BROOK DR\nSILVER SPRING, MD 20904\n
#
#                            LL        Lat          Lon                    Area  \
# 19534      39.0242, -77.1459)    39.0242     -77.1459     1000sq.ft-5000sq.ft
# 19535      39.0242, -77.1459)    39.0242     -77.1459     1000sq.ft-5000sq.ft
# 19536      39.0242, -77.1459)    39.0242     -77.1459     1000sq.ft-5000sq.ft
# 19537      39.0242, -77.1459)    39.0242     -77.1459     1000sq.ft-5000sq.ft
# 19551  39.126958, -77.166399)  39.126958   -77.166399        1sq.ft-1000sq.ft
# 19611      39.0242, -77.1459)    39.0242     -77.1459     1000sq.ft-5000sq.ft
# 19612      39.0242, -77.1459)    39.0242     -77.1459     1000sq.ft-5000sq.ft
# 19613      39.0242, -77.1459)    39.0242     -77.1459     1000sq.ft-5000sq.ft
# 19707  39.003017, -77.052556)  39.003017   -77.052556                     NaN
# 19775  39.173739, -77.274497)  39.173739   -77.274497    5000sq.ft-10000sq.ft
# ...                       ...        ...          ...                     ...
# 28755                    None       None         None     1000sq.ft-5000sq.ft
# 28757   39.00107, -77.178428)   39.00107   -77.178428        1sq.ft-1000sq.ft
# 28758  39.011428, -77.021668)  39.011428   -77.021668                     NaN
# 28763  39.100958, -77.212165)  39.100958   -77.212165        1sq.ft-1000sq.ft
# 28766  39.115081, -77.165139)  39.115081   -77.165139     1000sq.ft-5000sq.ft
# 28768                    None       None         None        1sq.ft-1000sq.ft
# 28769                    None       None         None        1sq.ft-1000sq.ft
# 28771  39.050583, -76.972137)  39.050583   -76.972137  50000sq.ft-160000sq.ft
# 28776  39.062785, -77.114051)  39.062785   -77.114051   21000sq.ft-50000sq.ft
# 28804  39.058567, -77.004873)  39.058567   -77.004873        1sq.ft-1000sq.ft
#
#           Value
# 19534   18k-60k
# 19535   18k-60k
# 19536   18k-60k
# 19537   18k-60k
# 19551   18k-60k
# 19611   18k-60k
# 19612   18k-60k
# 19613   18k-60k
# 19707    1k-10k
# 19775   200k-1m
# ...         ...
# 28755  60k-200k
# 28757  60k-200k
# 28758       NaN
# 28763   18k-60k
# 28766  60k-200k
# 28768  60k-200k
# 28769  60k-200k
# 28771   200k-1m
# 28776   200k-1m
# 28804   18k-60k
#
# [3375 rows x 24 columns]

# %%
#See how many contain revsion
T2 = D2.loc[(D2.Desc.str.contains("revision", case=False))]
T2.W_type.value_counts() 
# 3636 About 14 percent
# Out:
# ALTER                         2481
# CONSTRUCT                      767
# ADD                            190
# COMMERCIAL CHANGE OF USE       102
# RESTORE AND / OR REPAIR         54
# CONSTRUCT SHEETING/SHORING      21
# BUILD FOUNDATION                17
# INSTALL                          3
# REMOVE AND REPLACE               1
# Name: W_type, dtype: int64

# %% [markdown]
# # Visulaztion

# %%
Construction = D2.groupby

# %%
#sns.catplot(x="Status", kind="count", palette="ch:.25", data=D2);

# %%
permits_by_status = D2.groupby(D2['Status']).size()
plt.axis('equal') 
permits_by_status.plot(kind='pie', legend=False, label='Permits by Status');

# %%
D2['W_type'].value_counts().plot.bar();

# %%
D2['NewCity'].value_counts().plot.bar();

# %% [markdown]
# Wait Time

# %% [markdown]
# The department of permiting Issue 79.4 days as the Average:
# https://stat.montgomerycountymd.gov/stories/s/Department-of-Permitting-Services-DPS-/qaet-mgd9
# null 79

# %%
D3 = D2.assign(wait_time = (D2['I_date'] - D2['A_date']).dt.days)
D3
# Out:
#            P_num   Status St_num Pre_d         St_name St_suf Post_d  \
# 0         208677  Finaled  19850   N/A         CENTURY   BLVD    N/A
# 1         208678  Finaled  12901   N/A        PINNACLE     DR    N/A
# 2         208679  Finaled  12903   N/A        PINNACLE     DR    N/A
# 3         208689  Finaled  12907   N/A        PINNACLE     DR    N/A
# 4         208690  Finaled  12909   N/A        PINNACLE     DR    N/A
# 5         208691  Finaled  12925   N/A        PINNACLE     DR    N/A
# 6         208692   Issued  12935   N/A        PINNACLE     DR    N/A
# 7         208716  Finaled  16507     S       FREDERICK    AVE    N/A
# 8         208739  Finaled   8600   N/A  OLD GEORGETOWN     RD    N/A
# 9         208772  Finaled  12955   N/A        PINNACLE     DR    N/A
# ...          ...      ...    ...   ...             ...    ...    ...
# 28768     894100     Open  14239   N/A       DOWITCHER    WAY    N/A
# 28769     894102     Open  14236   N/A       DOWITCHER    WAY    N/A
# 28771     894147     Open  11800   N/A            TECH     RD    N/A
# 28772     894159     Open  19300   N/A         GEORGIA    AVE    N/A
# 28774     894298     Open   3415   N/A       OLANDWOOD     CT    N/A
# 28775     894346     Open   1776     E       JEFFERSON     ST    N/A
# 28776     894352     Open   5635   N/A         FISHERS     LN    N/A
# 28778     894436     Open      1   N/A       DISCOVERY     PL    N/A
# 28804     894600     Open    201   N/A    VALLEY BROOK     DR    N/A
# 28805  999211064     Open  14014   N/A     CONNECTICUT    AVE    N/A
#
#                 City    Zip     A_date     I_date               F_date  \
# 0         GERMANTOWN  20874 2000-01-03 2000-12-14  2001-10-10 00:00:00
# 1         GERMANTOWN  20874 2000-01-03 2000-12-14  2001-10-11 00:00:00
# 2         GERMANTOWN  20874 2000-01-03 2000-12-14  2001-10-12 00:00:00
# 3         GERMANTOWN  20874 2000-01-03 2000-12-14  2002-01-31 00:00:00
# 4         GERMANTOWN  20874 2000-01-03 2000-12-14  2002-01-29 00:00:00
# 5         GERMANTOWN  20874 2000-01-03 2000-12-14  2002-01-25 00:00:00
# 6         GERMANTOWN  20874 2000-01-03 2000-12-14                  N/A
# 7       GAITHERSBURG  20877 2000-01-03 2000-01-03  2000-01-19 00:00:00
# 8           BETHESDA  20817 2000-01-04 2000-01-27  2000-10-31 00:00:00
# 9         GERMANTOWN  20874 2000-01-04 2000-12-14  2001-12-21 00:00:00
# ...              ...    ...        ...        ...                  ...
# 28768          BOYDS  20841 2019-10-24        NaT                  N/A
# 28769          BOYDS  20841 2019-10-24        NaT                  N/A
# 28771  SILVER SPRING  20904 2019-10-24        NaT                  N/A
# 28772    BROOKEVILLE  20833 2019-10-24        NaT                  N/A
# 28774          OLNEY  20832 2019-10-25        NaT                  N/A
# 28775      ROCKVILLE  20852 2019-10-25        NaT                  N/A
# 28776      ROCKVILLE  20852 2019-10-25        NaT                  N/A
# 28778  SILVER SPRING  20910 2019-10-28        NaT                  N/A
# 28804  SILVER SPRING  20904 2019-10-28        NaT                  N/A
# 28805  SILVER SPRING  20906 2001-01-31        NaT                  N/A
#
#        Building_area      Decl_v  \
# 0            42600.0  1000000.00
# 1            42600.0  1000000.00
# 2            42600.0  1000000.00
# 3            63300.0  1500000.00
# 4            63300.0  1500000.00
# 5            63300.0  1500000.00
# 6            63300.0  1500000.00
# 7             3000.0    10000.00
# 8            10350.0   110000.00
# 9            36400.0   750000.00
# ...              ...         ...
# 28768          810.0   156854.00
# 28769          800.0   156854.00
# 28771        61257.0   742000.00
# 28772            0.0   196508.02
# 28774         1547.0   160000.00
# 28775          480.0   100000.00
# 28776        28510.0   210000.00
# 28778        39000.0  1000000.00
# 28804          625.0    39500.00
# 28805            1.0        1.00
#
#                                                     Desc  \
# 0                                                    N/A
# 1                                                    N/A
# 2                                                    N/A
# 3                                                    N/A
# 4                                                    N/A
# 5                                                    N/A
# 6                                                    N/A
# 7                                                    N/A
# 8      the applicant call on Wednesday, January 12, 2...
# 9                                                    N/A
# ...                                                  ...
# 28768  Customer Wants To Use ePlans,Entry Monument on...
# 28769  Customer Wants To Use ePlans,Entry Monument on...
# 28771  Customer Wants To Use ePlans Interior work onl...
# 28772                                   ADA IMPROVEMENTS
# 28774  *AO APPLICATION* ,NEW TENANT LAYOUT. NO CHANGE...
# 28775  Removing rusted steel beams from under buildin...
# 28776  Customer Wants To Use ePlans  Interior work on...
# 28778  Interior Alterations on FLOORS 3,4,5 &amp;6 - ...
# 28804  Customer Wants To Use ePlans,Sprint to install...
# 28805                                                N/A
#
#                         W_type                          U_code        NewCity  \
# 0                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 1                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 2                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 3                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 4                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 5                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 6                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 7                        ALTER               BUSINESS BUILDING   Gaithersburg
# 8                        ALTER          INSTITUTIONAL BUILDING       Bethesda
# 9                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# ...                        ...                             ...            ...
# 28768                CONSTRUCT  COMMERCIAL MISCELLANEOUS STRUC          Boyds
# 28769                CONSTRUCT  COMMERCIAL MISCELLANEOUS STRUC          Boyds
# 28771                    ALTER               BUSINESS BUILDING  Silver Spring
# 28772                    ALTER               ASSEMBLY BUILDING    Brookeville
# 28774                    ALTER               BUSINESS BUILDING          Olney
# 28775  RESTORE AND / OR REPAIR             MERCANTILE BUILDING      Rockville
# 28776                    ALTER               BUSINESS BUILDING      Rockville
# 28778                    ALTER               BUSINESS BUILDING  Silver Spring
# 28804                      ADD         MISCELLANEOUS STRUCTURE  Silver Spring
# 28805                    ALTER             MERCANTILE BUILDING  Silver Spring
#
#                                                 Address  \
# 0            19850 CENTURY BLVD\nGERMANTOWN, MD 20874\n
# 1             12901 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 2             12903 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 3             12907 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 4             12909 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 5             12925 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 6             12935 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 7         16507 FREDERICK AVE\nGAITHERSBURG, MD 20877\n
# 8          8600 OLD GEORGETOWN RD\nBETHESDA, MD 20817\n
# 9             12955 PINNACLE DR\nGERMANTOWN, MD 20874\n
# ...                                                 ...
# 28768              14239 DOWITCHER WAY\nBOYDS, MD 20841
# 28769              14236 DOWITCHER WAY\nBOYDS, MD 20841
# 28771          11800 TECH RD\nSILVER SPRING, MD 20904\n
# 28772        19300 GEORGIA AVE\nBROOKEVILLE, MD 20833\n
# 28774              3415 OLANDWOOD CT\nOLNEY, MD 20832\n
# 28775          1776 JEFFERSON ST\nROCKVILLE, MD 20852\n
# 28776            5635 FISHERS LN\nROCKVILLE, MD 20852\n
# 28778         1 DISCOVERY PL\nSILVER SPRING, MD 20910\n
# 28804    201 VALLEY BROOK DR\nSILVER SPRING, MD 20904\n
# 28805  14014 CONNECTICUT AVE\nSILVER SPRING, MD 20906\n
#
#                            LL        Lat          Lon                    Area  \
# 0       39.181866, -77.26558)  39.181866    -77.26558   21000sq.ft-50000sq.ft
# 1      39.182081, -77.265196)  39.182081   -77.265196   21000sq.ft-50000sq.ft
# 2      39.182361, -77.265512)  39.182361   -77.265512   21000sq.ft-50000sq.ft
# 3      39.182922, -77.266143)  39.182922   -77.266143  50000sq.ft-160000sq.ft
# 4      39.183215, -77.266444)  39.183215   -77.266444  50000sq.ft-160000sq.ft
# 5      39.183411, -77.266188)  39.183411   -77.266188  50000sq.ft-160000sq.ft
# 6       39.18353, -77.265984)   39.18353   -77.265984  50000sq.ft-160000sq.ft
# 7       39.127932, -77.18505)  39.127932    -77.18505     1000sq.ft-5000sq.ft
# 8       38.997251, -77.10922)  38.997251    -77.10922   10000sq.ft-20000sq.ft
# 9       39.18377, -77.265575)   39.18377   -77.265575   21000sq.ft-50000sq.ft
# ...                       ...        ...          ...                     ...
# 28768                    None       None         None        1sq.ft-1000sq.ft
# 28769                    None       None         None        1sq.ft-1000sq.ft
# 28771  39.050583, -76.972137)  39.050583   -76.972137  50000sq.ft-160000sq.ft
# 28772  39.176092, -77.058348)  39.176092   -77.058348                     NaN
# 28774   39.156018, -77.06703)  39.156018    -77.06703     1000sq.ft-5000sq.ft
# 28775  39.057447, -77.126308)  39.057447   -77.126308        1sq.ft-1000sq.ft
# 28776  39.062785, -77.114051)  39.062785   -77.114051   21000sq.ft-50000sq.ft
# 28778  38.994829, -77.027997)  38.994829   -77.027997   21000sq.ft-50000sq.ft
# 28804  39.058567, -77.004873)  39.058567   -77.004873        1sq.ft-1000sq.ft
# 28805  39.085193, -77.074968)  39.085193   -77.074968                     NaN
#
#           Value  wait_time
# 0       200k-1m      346.0
# 1       200k-1m      346.0
# 2       200k-1m      346.0
# 3         1m-5m      346.0
# 4         1m-5m      346.0
# 5         1m-5m      346.0
# 6         1m-5m      346.0
# 7        1k-10k        0.0
# 8      60k-200k       23.0
# 9       200k-1m      345.0
# ...         ...        ...
# 28768  60k-200k        NaN
# 28769  60k-200k        NaN
# 28771   200k-1m        NaN
# 28772  60k-200k        NaN
# 28774  60k-200k        NaN
# 28775  60k-200k        NaN
# 28776   200k-1m        NaN
# 28778   200k-1m        NaN
# 28804   18k-60k        NaN
# 28805       NaN        NaN
#
# [27633 rows x 25 columns]

# %%
D3['month'] = D3['A_date'].dt.month
D3['year'] = D3['A_date'].dt.year

# %%
_ = plt.figure(figsize=(18,10))
_ = plt.subplot(1,2,1)
_ = (D3.groupby('year').wait_time.mean()).plot.barh()
_ = plt.title('Average wait time by year')
_ = plt.subplot(1,2,2)
_ = (D3.groupby('year').wait_time.count()).plot.barh()
_ = plt.title('Permit count by year')
#Write a result

# %%
(D3.groupby('year').wait_time.mean())
# Out:
# year
# 2000     80.411894
# 2001     71.707337
# 2002     79.648841
# 2003    102.808230
# 2004    171.385852
# 2005    119.729798
# 2006    112.147161
# 2007    113.519558
# 2008     89.181915
# 2009     79.608027
# 2010     91.859200
# 2011    127.611851
# 2012     80.542497
# 2013     75.584200
# 2014     87.104506
# 2015     84.302293
# 2016     72.584227
# 2017     81.320165
# 2018     90.871073
# 2019     60.782872
# Name: wait_time, dtype: float64

# %%
_ = plt.figure(figsize=(15,6))
ax = sns.boxplot(y='W_type', x='wait_time', data = D3, orient = 'h');
plt.title('permit_type vs. wait_time');
plt.tight_layout(pad=1)
plt.xlim(0, 500)
plt.show()

# %% [markdown]
# Conclusion: The longest wait time is Construction followed by Alterations. While Alterations have the greatest percentage in this data set Construction beats out Alteration in terms of "Wait Time"

# %%
D3
# Out:
#            P_num   Status St_num Pre_d         St_name St_suf Post_d  \
# 0         208677  Finaled  19850   N/A         CENTURY   BLVD    N/A
# 1         208678  Finaled  12901   N/A        PINNACLE     DR    N/A
# 2         208679  Finaled  12903   N/A        PINNACLE     DR    N/A
# 3         208689  Finaled  12907   N/A        PINNACLE     DR    N/A
# 4         208690  Finaled  12909   N/A        PINNACLE     DR    N/A
# 5         208691  Finaled  12925   N/A        PINNACLE     DR    N/A
# 6         208692   Issued  12935   N/A        PINNACLE     DR    N/A
# 7         208716  Finaled  16507     S       FREDERICK    AVE    N/A
# 8         208739  Finaled   8600   N/A  OLD GEORGETOWN     RD    N/A
# 9         208772  Finaled  12955   N/A        PINNACLE     DR    N/A
# ...          ...      ...    ...   ...             ...    ...    ...
# 28768     894100     Open  14239   N/A       DOWITCHER    WAY    N/A
# 28769     894102     Open  14236   N/A       DOWITCHER    WAY    N/A
# 28771     894147     Open  11800   N/A            TECH     RD    N/A
# 28772     894159     Open  19300   N/A         GEORGIA    AVE    N/A
# 28774     894298     Open   3415   N/A       OLANDWOOD     CT    N/A
# 28775     894346     Open   1776     E       JEFFERSON     ST    N/A
# 28776     894352     Open   5635   N/A         FISHERS     LN    N/A
# 28778     894436     Open      1   N/A       DISCOVERY     PL    N/A
# 28804     894600     Open    201   N/A    VALLEY BROOK     DR    N/A
# 28805  999211064     Open  14014   N/A     CONNECTICUT    AVE    N/A
#
#                 City    Zip     A_date     I_date               F_date  \
# 0         GERMANTOWN  20874 2000-01-03 2000-12-14  2001-10-10 00:00:00
# 1         GERMANTOWN  20874 2000-01-03 2000-12-14  2001-10-11 00:00:00
# 2         GERMANTOWN  20874 2000-01-03 2000-12-14  2001-10-12 00:00:00
# 3         GERMANTOWN  20874 2000-01-03 2000-12-14  2002-01-31 00:00:00
# 4         GERMANTOWN  20874 2000-01-03 2000-12-14  2002-01-29 00:00:00
# 5         GERMANTOWN  20874 2000-01-03 2000-12-14  2002-01-25 00:00:00
# 6         GERMANTOWN  20874 2000-01-03 2000-12-14                  N/A
# 7       GAITHERSBURG  20877 2000-01-03 2000-01-03  2000-01-19 00:00:00
# 8           BETHESDA  20817 2000-01-04 2000-01-27  2000-10-31 00:00:00
# 9         GERMANTOWN  20874 2000-01-04 2000-12-14  2001-12-21 00:00:00
# ...              ...    ...        ...        ...                  ...
# 28768          BOYDS  20841 2019-10-24        NaT                  N/A
# 28769          BOYDS  20841 2019-10-24        NaT                  N/A
# 28771  SILVER SPRING  20904 2019-10-24        NaT                  N/A
# 28772    BROOKEVILLE  20833 2019-10-24        NaT                  N/A
# 28774          OLNEY  20832 2019-10-25        NaT                  N/A
# 28775      ROCKVILLE  20852 2019-10-25        NaT                  N/A
# 28776      ROCKVILLE  20852 2019-10-25        NaT                  N/A
# 28778  SILVER SPRING  20910 2019-10-28        NaT                  N/A
# 28804  SILVER SPRING  20904 2019-10-28        NaT                  N/A
# 28805  SILVER SPRING  20906 2001-01-31        NaT                  N/A
#
#        Building_area      Decl_v  \
# 0            42600.0  1000000.00
# 1            42600.0  1000000.00
# 2            42600.0  1000000.00
# 3            63300.0  1500000.00
# 4            63300.0  1500000.00
# 5            63300.0  1500000.00
# 6            63300.0  1500000.00
# 7             3000.0    10000.00
# 8            10350.0   110000.00
# 9            36400.0   750000.00
# ...              ...         ...
# 28768          810.0   156854.00
# 28769          800.0   156854.00
# 28771        61257.0   742000.00
# 28772            0.0   196508.02
# 28774         1547.0   160000.00
# 28775          480.0   100000.00
# 28776        28510.0   210000.00
# 28778        39000.0  1000000.00
# 28804          625.0    39500.00
# 28805            1.0        1.00
#
#                                                     Desc  \
# 0                                                    N/A
# 1                                                    N/A
# 2                                                    N/A
# 3                                                    N/A
# 4                                                    N/A
# 5                                                    N/A
# 6                                                    N/A
# 7                                                    N/A
# 8      the applicant call on Wednesday, January 12, 2...
# 9                                                    N/A
# ...                                                  ...
# 28768  Customer Wants To Use ePlans,Entry Monument on...
# 28769  Customer Wants To Use ePlans,Entry Monument on...
# 28771  Customer Wants To Use ePlans Interior work onl...
# 28772                                   ADA IMPROVEMENTS
# 28774  *AO APPLICATION* ,NEW TENANT LAYOUT. NO CHANGE...
# 28775  Removing rusted steel beams from under buildin...
# 28776  Customer Wants To Use ePlans  Interior work on...
# 28778  Interior Alterations on FLOORS 3,4,5 &amp;6 - ...
# 28804  Customer Wants To Use ePlans,Sprint to install...
# 28805                                                N/A
#
#                         W_type                          U_code        NewCity  \
# 0                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 1                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 2                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 3                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 4                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 5                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 6                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# 7                        ALTER               BUSINESS BUILDING   Gaithersburg
# 8                        ALTER          INSTITUTIONAL BUILDING       Bethesda
# 9                    CONSTRUCT           MULTI-FAMILY DWELLING     Germantown
# ...                        ...                             ...            ...
# 28768                CONSTRUCT  COMMERCIAL MISCELLANEOUS STRUC          Boyds
# 28769                CONSTRUCT  COMMERCIAL MISCELLANEOUS STRUC          Boyds
# 28771                    ALTER               BUSINESS BUILDING  Silver Spring
# 28772                    ALTER               ASSEMBLY BUILDING    Brookeville
# 28774                    ALTER               BUSINESS BUILDING          Olney
# 28775  RESTORE AND / OR REPAIR             MERCANTILE BUILDING      Rockville
# 28776                    ALTER               BUSINESS BUILDING      Rockville
# 28778                    ALTER               BUSINESS BUILDING  Silver Spring
# 28804                      ADD         MISCELLANEOUS STRUCTURE  Silver Spring
# 28805                    ALTER             MERCANTILE BUILDING  Silver Spring
#
#                                                 Address  \
# 0            19850 CENTURY BLVD\nGERMANTOWN, MD 20874\n
# 1             12901 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 2             12903 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 3             12907 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 4             12909 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 5             12925 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 6             12935 PINNACLE DR\nGERMANTOWN, MD 20874\n
# 7         16507 FREDERICK AVE\nGAITHERSBURG, MD 20877\n
# 8          8600 OLD GEORGETOWN RD\nBETHESDA, MD 20817\n
# 9             12955 PINNACLE DR\nGERMANTOWN, MD 20874\n
# ...                                                 ...
# 28768              14239 DOWITCHER WAY\nBOYDS, MD 20841
# 28769              14236 DOWITCHER WAY\nBOYDS, MD 20841
# 28771          11800 TECH RD\nSILVER SPRING, MD 20904\n
# 28772        19300 GEORGIA AVE\nBROOKEVILLE, MD 20833\n
# 28774              3415 OLANDWOOD CT\nOLNEY, MD 20832\n
# 28775          1776 JEFFERSON ST\nROCKVILLE, MD 20852\n
# 28776            5635 FISHERS LN\nROCKVILLE, MD 20852\n
# 28778         1 DISCOVERY PL\nSILVER SPRING, MD 20910\n
# 28804    201 VALLEY BROOK DR\nSILVER SPRING, MD 20904\n
# 28805  14014 CONNECTICUT AVE\nSILVER SPRING, MD 20906\n
#
#                            LL        Lat          Lon                    Area  \
# 0       39.181866, -77.26558)  39.181866    -77.26558   21000sq.ft-50000sq.ft
# 1      39.182081, -77.265196)  39.182081   -77.265196   21000sq.ft-50000sq.ft
# 2      39.182361, -77.265512)  39.182361   -77.265512   21000sq.ft-50000sq.ft
# 3      39.182922, -77.266143)  39.182922   -77.266143  50000sq.ft-160000sq.ft
# 4      39.183215, -77.266444)  39.183215   -77.266444  50000sq.ft-160000sq.ft
# 5      39.183411, -77.266188)  39.183411   -77.266188  50000sq.ft-160000sq.ft
# 6       39.18353, -77.265984)   39.18353   -77.265984  50000sq.ft-160000sq.ft
# 7       39.127932, -77.18505)  39.127932    -77.18505     1000sq.ft-5000sq.ft
# 8       38.997251, -77.10922)  38.997251    -77.10922   10000sq.ft-20000sq.ft
# 9       39.18377, -77.265575)   39.18377   -77.265575   21000sq.ft-50000sq.ft
# ...                       ...        ...          ...                     ...
# 28768                    None       None         None        1sq.ft-1000sq.ft
# 28769                    None       None         None        1sq.ft-1000sq.ft
# 28771  39.050583, -76.972137)  39.050583   -76.972137  50000sq.ft-160000sq.ft
# 28772  39.176092, -77.058348)  39.176092   -77.058348                     NaN
# 28774   39.156018, -77.06703)  39.156018    -77.06703     1000sq.ft-5000sq.ft
# 28775  39.057447, -77.126308)  39.057447   -77.126308        1sq.ft-1000sq.ft
# 28776  39.062785, -77.114051)  39.062785   -77.114051   21000sq.ft-50000sq.ft
# 28778  38.994829, -77.027997)  38.994829   -77.027997   21000sq.ft-50000sq.ft
# 28804  39.058567, -77.004873)  39.058567   -77.004873        1sq.ft-1000sq.ft
# 28805  39.085193, -77.074968)  39.085193   -77.074968                     NaN
#
#           Value  wait_time  month  year
# 0       200k-1m      346.0      1  2000
# 1       200k-1m      346.0      1  2000
# 2       200k-1m      346.0      1  2000
# 3         1m-5m      346.0      1  2000
# 4         1m-5m      346.0      1  2000
# 5         1m-5m      346.0      1  2000
# 6         1m-5m      346.0      1  2000
# 7        1k-10k        0.0      1  2000
# 8      60k-200k       23.0      1  2000
# 9       200k-1m      345.0      1  2000
# ...         ...        ...    ...   ...
# 28768  60k-200k        NaN     10  2019
# 28769  60k-200k        NaN     10  2019
# 28771   200k-1m        NaN     10  2019
# 28772  60k-200k        NaN     10  2019
# 28774  60k-200k        NaN     10  2019
# 28775  60k-200k        NaN     10  2019
# 28776   200k-1m        NaN     10  2019
# 28778   200k-1m        NaN     10  2019
# 28804   18k-60k        NaN     10  2019
# 28805       NaN        NaN      1  2001
#
# [27633 rows x 27 columns]

# %%
D3['year'], D3['month'], D3['day_of_week'] = D3.A_date.dt.year, D3.A_date.dt.month, D3.A_date.dt.dayofweek

# %% [markdown]
# Select this year and this year

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x="year", data=D3);

# %%
sns.countplot(x="day_of_week", data=D3);

# %%
sns.countplot(x="month", data=D3);
#most permits were filed in the summer

# %% [markdown]
# Conclusion: The majority of permits are submitted on Sunday through Thursday

# %%
D3.groupby('year').P_num.count()
# Out:
# year
# 2000     926
# 2001    1289
# 2002    1134
# 2003    1256
# 2004    1258
# 2005    1220
# 2006     892
# 2007    1249
# 2008     989
# 2009    1202
# 2010    1279
# 2011    1546
# 2012    1554
# 2013    1493
# 2014    1663
# 2015    1554
# 2016    1641
# 2017    1780
# 2018    1979
# 2019    1729
# Name: P_num, dtype: int64

# %%
DTime = D3.set_index('A_date')
T4 = D3.loc[(D2.Desc.str.contains("solar panel", case=False))]
DTime1 = T4.set_index('A_date')

# %% [markdown]
# What caused the big spike in 2011 and 2004.

# %%
permits_by_type = D2.groupby(['U_code']).size()
permits_by_type.sort_values(ascending=False, inplace=True)
permits_by_type.head(5)
# Out:
# U_code
# BUSINESS BUILDING                 6926
# MULTI-FAMILY DWELLING             4571
# COMMERCIAL MISCELLANEOUS STRUC    2840
# MERCANTILE BUILDING               2255
# TOWNHOUSE                         1688
# dtype: int64

# %%
filtered_permits = list(permits_by_type.head(5).index)
filtered_permits
# Out:
# ['BUSINESS BUILDING',
#  'MULTI-FAMILY DWELLING',
#  'COMMERCIAL MISCELLANEOUS STRUC',
#  'MERCANTILE BUILDING',
#  'TOWNHOUSE']

# %%
filtered_df = D2.loc[D2['U_code'].isin(filtered_permits)]
filtered_df.head()
# Out:
#     P_num   Status St_num Pre_d   St_name St_suf Post_d        City    Zip  \
# 0  208677  Finaled  19850   N/A   CENTURY   BLVD    N/A  GERMANTOWN  20874
# 1  208678  Finaled  12901   N/A  PINNACLE     DR    N/A  GERMANTOWN  20874
# 2  208679  Finaled  12903   N/A  PINNACLE     DR    N/A  GERMANTOWN  20874
# 3  208689  Finaled  12907   N/A  PINNACLE     DR    N/A  GERMANTOWN  20874
# 4  208690  Finaled  12909   N/A  PINNACLE     DR    N/A  GERMANTOWN  20874
#
#       A_date     I_date               F_date  Building_area     Decl_v Desc  \
# 0 2000-01-03 2000-12-14  2001-10-10 00:00:00        42600.0  1000000.0  N/A
# 1 2000-01-03 2000-12-14  2001-10-11 00:00:00        42600.0  1000000.0  N/A
# 2 2000-01-03 2000-12-14  2001-10-12 00:00:00        42600.0  1000000.0  N/A
# 3 2000-01-03 2000-12-14  2002-01-31 00:00:00        63300.0  1500000.0  N/A
# 4 2000-01-03 2000-12-14  2002-01-29 00:00:00        63300.0  1500000.0  N/A
#
#       W_type                 U_code     NewCity  \
# 0  CONSTRUCT  MULTI-FAMILY DWELLING  Germantown
# 1  CONSTRUCT  MULTI-FAMILY DWELLING  Germantown
# 2  CONSTRUCT  MULTI-FAMILY DWELLING  Germantown
# 3  CONSTRUCT  MULTI-FAMILY DWELLING  Germantown
# 4  CONSTRUCT  MULTI-FAMILY DWELLING  Germantown
#
#                                       Address                      LL  \
# 0  19850 CENTURY BLVD\nGERMANTOWN, MD 20874\n   39.181866, -77.26558)
# 1   12901 PINNACLE DR\nGERMANTOWN, MD 20874\n  39.182081, -77.265196)
# 2   12903 PINNACLE DR\nGERMANTOWN, MD 20874\n  39.182361, -77.265512)
# 3   12907 PINNACLE DR\nGERMANTOWN, MD 20874\n  39.182922, -77.266143)
# 4   12909 PINNACLE DR\nGERMANTOWN, MD 20874\n  39.183215, -77.266444)
#
#          Lat          Lon                    Area    Value
# 0  39.181866    -77.26558   21000sq.ft-50000sq.ft  200k-1m
# 1  39.182081   -77.265196   21000sq.ft-50000sq.ft  200k-1m
# 2  39.182361   -77.265512   21000sq.ft-50000sq.ft  200k-1m
# 3  39.182922   -77.266143  50000sq.ft-160000sq.ft    1m-5m
# 4  39.183215   -77.266444  50000sq.ft-160000sq.ft    1m-5m

# %%
DTime['num'] = 1
DTime['num'].resample('M').sum().plot();

# %%
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(1, 1, 1)

ax.plot(DTime['num'].resample('M').sum(), 'k', label='Total permits')
for use_code in filtered_permits:
    x = DTime[DTime.U_code == use_code]['num'].resample('M').sum()
    ax.plot(x, label=use_code)
ax.legend();

# %%
permits_by_type1 = D2.groupby(['W_type']).size()
permits_by_type1.sort_values(ascending=False, inplace=True)
permits_by_type1.head(5)
filtered_permits1 = list(permits_by_type1.head(5).index)
filtered_permits1
filtered_df1 = D2.loc[D2['W_type'].isin(filtered_permits1)]
filtered_df1.head()
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(1, 1, 1)

ax.plot(DTime['num'].resample('M').sum(), 'k', label='Total permits')
for work in filtered_permits1:
    x = DTime[DTime.W_type == work]['num'].resample('M').sum()
    ax.plot(x, label=work)
ax.legend();

# %% [markdown]
# The greatest spike was in construction and in the multi-family housing projects.

# %%
D3.to_csv('D3',index=False)

# %%
Ir = D3.loc[D3.I_date.isnull()]
Ir.year.value_counts().sum()
# Most are in 2019 and 2018 706 out of 1532
# Out:
# 1531

# %%
# Resampleing by year
DTime1['num'] = 1
DTime1['num'].resample('y').sum().plot();

# %% [markdown]
# # MAPS

# %% [markdown]
# Goals:
# 1. To show the distribution of permits
# 2. To show a change in the the types of permits done
# 3. Showing a map of open permits
# 4. Showing a map of "finalled"
# 5. Show map with type of construction
# 6. Make a heat map
# 7. Compare two different years
# 8. Show Solar panels
# 9. Show a map by highest value

# %% [markdown]
# Link to Maps
# https://public.tableau.com/profile/abraham.lewis#!/vizhome/Book1_15754944071890/Sheet3
# https://public.tableau.com/profile/abraham.lewis#!/vizhome/Book1_15754944071890/Sheet4
# https://public.tableau.com/profile/abraham.lewis#!/vizhome/Book1_15754944071890/Sheet5
# https://public.tableau.com/profile/abraham.lewis#!/vizhome/Book1_15754944071890/Sheet6

# %% [markdown]
#  # Statistical analysis

# %% [markdown]
# 1. Using Anova for Value and New City
# 2. Show the correlation between Area and Work Type.
# 3. Show the correlation between Value and Use code.
# 4. Using a T-test for the Mean Value

# %% [markdown]
# Seeing if there is a connection between work type and valuation

# %%
CH = filtered_df[['U_code', 'Value']]
CH.head()
# Out:
#                   U_code    Value
# 0  MULTI-FAMILY DWELLING  200k-1m
# 1  MULTI-FAMILY DWELLING  200k-1m
# 2  MULTI-FAMILY DWELLING  200k-1m
# 3  MULTI-FAMILY DWELLING    1m-5m
# 4  MULTI-FAMILY DWELLING    1m-5m

# %%
CH['U_code'].value_counts()
# Total permits 18280 about 67 percent of all permits so a good represntation
# Out:
# BUSINESS BUILDING                 6926
# MULTI-FAMILY DWELLING             4571
# COMMERCIAL MISCELLANEOUS STRUC    2840
# MERCANTILE BUILDING               2255
# TOWNHOUSE                         1688
# Name: U_code, dtype: int64

# %% [markdown]
# H0:There is no statistically significant relationship between the Use code and the value of of a permit.
# Ha:There is a statistically significant relationship between the Use code and the value of a permit.

# %%
contingency_table = pd.crosstab(
    CH['U_code'],
    CH['Value'],
    margins = False
)
contingency_table
# Out:
# Value                           1k-10k  10k-18k  18k-60k  60k-200k  200k-1m  \
# U_code
# BUSINESS BUILDING                  630      451     1761      1755     1482
# COMMERCIAL MISCELLANEOUS STRUC     771      419     1025       296      147
# MERCANTILE BUILDING                280      118      531       609      421
# MULTI-FAMILY DWELLING              597      164     1058      1301      536
# TOWNHOUSE                           95       22       30       994      529
#
# Value                           1m-5m  5m-10m  10m-20m  20m-50m  50m-100M  \
# U_code
# BUSINESS BUILDING                 389      60       40       24         6
# COMMERCIAL MISCELLANEOUS STRUC     41       2        4        3         0
# MERCANTILE BUILDING               122      13        8        6         1
# MULTI-FAMILY DWELLING             289      34       27       36        12
# TOWNHOUSE                           7       0        0        0         0
#
# Value                           100m- 2b
# U_code
# BUSINESS BUILDING                      1
# COMMERCIAL MISCELLANEOUS STRUC         0
# MERCANTILE BUILDING                    1
# MULTI-FAMILY DWELLING                  0
# TOWNHOUSE                              0

# %%
from scipy import stats
stats.chi2_contingency(contingency_table)
# Out:
# (3241.969701275461,
#  0.0,
#  40,
#  array([[9.13192617e+02, 4.51785981e+02, 1.69515949e+03, 1.90681391e+03,
#          1.19873367e+03, 3.26332634e+02, 4.19460578e+01, 3.04012713e+01,
#          2.65530091e+01, 7.31169816e+00, 7.69652438e-01],
#         [3.74742477e+02, 1.85397247e+02, 6.95634476e+02, 7.82490086e+02,
#          4.91918591e+02, 1.33915559e+02, 1.72132027e+01, 1.24756240e+01,
#          1.08964311e+01, 3.00046653e+00, 3.15838582e-01],
#         [2.91989153e+02, 1.44456496e+02, 5.42019477e+02, 6.09695008e+02,
#          3.83289596e+02, 1.04343364e+02, 1.34120597e+01, 9.72066713e+00,
#          8.49020294e+00, 2.33788197e+00, 2.46092839e-01],
#         [5.61006648e+02, 2.77548169e+02, 1.04139666e+03, 1.17142349e+03,
#          7.36424656e+02, 2.00477723e+02, 2.57689526e+01, 1.86765804e+01,
#          1.63124563e+01, 4.49183578e+00, 4.72824819e-01],
#         [2.32069104e+02, 1.14812106e+02, 4.30789888e+02, 4.84577502e+02,
#          3.04633485e+02, 8.29307208e+01, 1.06597271e+01, 7.72585724e+00,
#          6.74790063e+00, 1.85811756e+00, 1.95591323e-01]]))

# %% [markdown]
# H0:There is no statistically significant relationship between the Work type and the Area of of a permit.
# Ha:There is a statistically significant relationship between the Work type and the Area of a permit.

# %%
permits_by_w = D2.groupby(['W_type']).size()
permits_by_w.sort_values(ascending=False, inplace=True)
filtered_permits1 = list(permits_by_w.head(4).index)
filtered_permits1
filtered_df1 = D2.loc[D2['W_type'].isin(filtered_permits1)]
permits_by_w.head(4)
AC = filtered_df1[['W_type', 'Area']]
AC['W_type'].value_counts()
# Out:
# ALTER                      14928
# CONSTRUCT                   7625
# ADD                         2495
# RESTORE AND / OR REPAIR     1454
# Name: W_type, dtype: int64

# %%
contingency_table1 = pd.crosstab(
    AC['W_type'],
    AC['Area'],
    margins = False
)
contingency_table1
# Out:
# Area                     1sq.ft-1000sq.ft  1000sq.ft-5000sq.ft  \
# W_type
# ADD                                  1245                  435
# ALTER                                3634                 5461
# CONSTRUCT                            1717                 4079
# RESTORE AND / OR REPAIR               591                  303
#
# Area                     5000sq.ft-10000sq.ft  10000sq.ft-20000sq.ft  \
# W_type
# ADD                                       110                     73
# ALTER                                    1386                   1058
# CONSTRUCT                                 334                    362
# RESTORE AND / OR REPAIR                    96                     52
#
# Area                     20000sq.ft-21000sq.ft  21000sq.ft-50000sq.ft  \
# W_type
# ADD                                          5                     84
# ALTER                                       43                    694
# CONSTRUCT                                   18                    269
# RESTORE AND / OR REPAIR                      6                     51
#
# Area                     50000sq.ft-160000sq.ft
# W_type
# ADD                                          55
# ALTER                                       395
# CONSTRUCT                                   298
# RESTORE AND / OR REPAIR                      51

# %%
stats.chi2_contingency(contingency_table1)
# Out:
# (1884.2908909162288,
#  0.0,
#  18,
#  array([[6.29744990e+02, 9.00587033e+02, 1.68761493e+02, 1.35377210e+02,
#          6.30884086e+00, 9.62098232e+01, 7.00106090e+01],
#         [3.97583397e+03, 5.68576896e+03, 1.06545933e+03, 8.54690897e+02,
#          3.98302554e+01, 6.07411395e+02, 4.42005195e+02],
#         [2.22058062e+03, 3.17561257e+03, 5.95079764e+02, 4.77361493e+02,
#          2.22459725e+01, 3.39251081e+02, 2.46868500e+02],
#         [3.60840428e+02, 5.16031434e+02, 9.66994106e+01, 7.75703995e+01,
#          3.61493124e+00, 5.51277014e+01, 4.01156953e+01]]))

# %% [markdown]
# In the first example I am doing a Chi-Square test comparing the the bins of Value with Use code.
# * The Chi Statistic - 3241.969701275461, the P_vale is 0.0 so less than .05 therefore we reject the null hypothesis that there is no difference between the mean and we conclude that there is a connection between a permits value and its Use code.
# * 40 - the degrees of freedom
# In the Second example I did another Chi-Square test comparing the the bins of Area with Work Type.
# * The Chi Statistic -1884.2908909162288 , the P_vale is 0.0 so less than .05 therefore we reject the null hypothesis that there is no difference between the mean and we conclude that there is a connection between the Area of a permit and the Work Type.
# * 18 - the degrees of freedom

# %%
DA = pd.read_csv('data.csv')
DA
#DA.PopTotal.sum()
list(D2.columns)
# Out:
# ['P_num',
#  'Status',
#  'St_num',
#  'Pre_d',
#  'St_name',
#  'St_suf',
#  'Post_d',
#  'City',
#  'Zip',
#  'A_date',
#  'I_date',
#  'F_date',
#  'Building_area',
#  'Decl_v',
#  'Desc',
#  'W_type',
#  'U_code',
#  'NewCity',
#  'Address',
#  'LL',
#  'Lat',
#  'Lon',
#  'Area',
#  'Value']

# %%
list(D2.columns) 
D4 = D2.reindex(columns=['P_num','Status','St_num','Pre_d','St_name','St_suf','Post_d','City','Zip','A_date','I_date',
'F_date','Building_area','Decl_v','Desc','W_type','U_code','NewCity','Address','LL','Lat','Lon','Value'])
df_anova = D4[['Decl_v','NewCity']]
grps = pd.unique(df_anova.Decl_v.values)

# %% [markdown]
# ANOVA In this example example is being used in order to test whether Value of the permits differs based on some categorical variable like City, we have to compare the means of each level or group the variable. The analysis here is one of variance as ANOVA is a statistical inference test that lets you compare multiple groups at the same time.
# F = Between group variability / Within group variability
# There are 3 different Cities and their Values and here I am checking whether all 3 group are similar or not.

# %%
# I got Anova to work and right before I uploaded it it stopped working 
# I tried to fix it with and exception statement but it didnt work
#from scipy import stats
#from statsmodels.stats import weightstats as stests
#df_anova = D4[['Decl_v','NewCity']]
#grps = pd.unique(df_anova.NewCity.values)
#d_data = {grp:df_anova['Decl_v'][df_anova.NewCity == grp] for grp in grps}
#try:
    #F, p = stats.f_oneway(D4.loc[(D4.NewCity == 'Rockville')], D4.loc[(D4.NewCity=='Silver Spring')], D4.loc[D4.NewCity == 'Bethesda'])
#except ValueError:
    #print("p-value for significance is: ", p)
#if np.all(p<0.05):
    #print("reject null hypothesis")
#else:
    #print("accept null hypothesis")

# %% [markdown]
# We accept the null hypothesis that the 3 are similar.

# %%
#checking the Mean for Decl_v
from scipy.stats import ttest_1samp
Val = D2['Decl_v']
Val_mean = np.mean(Val)
print(Val_mean)
tset, pval = ttest_1samp(Val, 50000)
print(pval)
if pval < 0.05:    # alpha value is 0.05 or 5%
   print(" we reject the  null hypothesis")
else:
  print("we accept the null hypothesis")
# Out:
# 761652.7176296487
# 5.802495665200189e-47
#  we reject the  null hypothesis

# %% [markdown]
# We reject the null hypothesis of 50000 being the mean.

# %%
City = D4['NewCity'].value_counts().head()

# %%
corr = D2.loc[:,D2.dtypes == 'float64'].corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 10, as_cmap=True));
# scatter plot line best fit

# %% [markdown]
# Going through sums of different cites and work types in the county

# %%
D2S = D2.loc[D2.NewCity == 'Silver Spring' ]
D2B = D2.loc[D2.NewCity == 'Bethesda' ]
D2R = D2.loc[D2.NewCity == 'Rockville' ]
D2G = D2.loc[D2.NewCity == 'Germantown']
D2C = D2.loc[D2.NewCity == 'Clarksburg' ]

# %%
display(D2S['P_num'].value_counts().sum())
display(D2B['P_num'].value_counts().sum())
display(D2R['P_num'].value_counts().sum())
display(D2G['P_num'].value_counts().sum())
display(D2C['P_num'].value_counts().sum())
#19656 72% 0f all permits
# Out:
# 6954
# 4513
# 3471
# 2802
# 1916

# %%
D2.P_num = D2.P_num.astype(str)
display(D2S['Decl_v'].sum())
display(D2B['Decl_v'].sum())
display(D2R['Decl_v'].sum())
display(D2G['Decl_v'].sum())
display(D2C['Decl_v'].sum())
# Out:
# 5324379340.01
# 3756550714.2400002
# 5374386392.95
# 1722628345.3
# 459812873.35

# %%
display(D2S['W_type'].value_counts())
display(D2B['W_type'].value_counts())
display(D2R['W_type'].value_counts())
display(D2G['W_type'].value_counts())
display(D2C['W_type'].value_counts())
# Out:
# ALTER                         4064
# CONSTRUCT                     1378
# ADD                            717
# RESTORE AND / OR REPAIR        469
# COMMERCIAL CHANGE OF USE       222
# BUILD FOUNDATION                44
# CONSTRUCT SHEETING/SHORING      32
# INSTALL                         24
# DEMOLISH                         2
# REMOVE AND REPLACE               2
# Name: W_type, dtype: int64
# ALTER                         2844
# CONSTRUCT                      853
# ADD                            406
# RESTORE AND / OR REPAIR        248
# COMMERCIAL CHANGE OF USE        77
# CONSTRUCT SHEETING/SHORING      48
# BUILD FOUNDATION                24
# INSTALL                         12
# REPLACE                          1
# Name: W_type, dtype: int64
# ALTER                         2223
# CONSTRUCT                      598
# ADD                            272
# RESTORE AND / OR REPAIR        219
# COMMERCIAL CHANGE OF USE        74
# BUILD FOUNDATION                46
# CONSTRUCT SHEETING/SHORING      24
# INSTALL                          9
# REPLACE                          2
# FINAL ONLY AP                    2
# REMOVE AND REPLACE               2
# Name: W_type, dtype: int64
# ALTER                       1246
# CONSTRUCT                   1124
# ADD                          166
# RESTORE AND / OR REPAIR      156
# COMMERCIAL CHANGE OF USE      48
# REMOVE AND REPLACE            38
# BUILD FOUNDATION              11
# REPLACE                        6
# INSTALL                        6
# FINAL ONLY AP                  1
# Name: W_type, dtype: int64
# CONSTRUCT                   1577
# ALTER                        250
# ADD                           70
# RESTORE AND / OR REPAIR        7
# COMMERCIAL CHANGE OF USE       6
# BUILD FOUNDATION               6
# Name: W_type, dtype: int64

# %%
display(D2S['U_code'].value_counts())
display(D2B['U_code'].value_counts())
display(D2R['U_code'].value_counts())
display(D2G['U_code'].value_counts())
display(D2C['U_code'].value_counts())
# Out:
# BUSINESS BUILDING                 1519
# MULTI-FAMILY DWELLING             1417
# COMMERCIAL MISCELLANEOUS STRUC     671
# MERCANTILE BUILDING                644
# RESTAURANT                         504
# EDUCATIONAL BUILDING               354
# TOWNHOUSE                          349
# ASSEMBLY BUILDING                  225
# MULTIFAMILY DWELLING LOW RISE      155
# PLACE OF WORSHIP                   148
#                                   ...
# FACTORY AND INDUST, MOD HAZ          2
# STORAGE, LOW HAZARD                  1
# ASSEMBLY, THEATERS, W/STAGE          1
# POOL - ABOVE GROUND                  1
# BOARDING HOUSE                       1
# RESIDENTIAL, MULTIPLE FAMILY         1
# FACTORY                              1
# DUMPSTER                             1
# FACTORY AND INDUST, LOW HAZ          1
# ASSEMBLY, NIGHTCLUBS                 1
# Name: U_code, Length: 53, dtype: int64
# BUSINESS BUILDING                   1557
# MERCANTILE BUILDING                  430
# COMMERCIAL MISCELLANEOUS STRUC       396
# RESTAURANT                           318
# TOWNHOUSE                            303
# MULTI-FAMILY DWELLING                298
# EDUCATIONAL BUILDING                 224
# ASSEMBLY BUILDING                    198
# MULTIFAMILY DWELLING HIGH RISE       111
# HOSPITAL                              81
#                                     ...
# SIGN                                   2
# SWIMMING POOL & FENCE                  2
# ASSEMBLY, CHURCHES                     1
# INSTITUTIONAL, INCAPACITATED           1
# FACTORY AND INDUST, MOD HAZ            1
# INSTITUTIONAL, SUPV ENVIRONMNT         1
# SENIOR RESIDENTIAL CARE FACILITY       1
# DAY CARE                               1
# BOARDING HOUSE                         1
# ASSEMBLY, OUTSIDE ACTIVITY             1
# Name: U_code, Length: 47, dtype: int64
# BUSINESS BUILDING                   1349
# MULTI-FAMILY DWELLING                326
# MERCANTILE BUILDING                  275
# COMMERCIAL MISCELLANEOUS STRUC       265
# RESTAURANT                           150
# ASSEMBLY BUILDING                    137
# EDUCATIONAL BUILDING                 127
# BIOSCIENCE                           124
# STORAGE BUILDING                     101
# HOSPITAL                              77
#                                     ...
# EDUCATIONAL                            2
# SENIOR RESIDENTIAL CARE FACILITY       2
# DAY CARE                               2
# ASSEMBLY, RESTAURANTS                  2
# INSTITUTIONAL, NURSING HOMES           1
# SWIMMING POOL & FENCE                  1
# RESIDENTIAL, HOTELS                    1
# INSTITUTIONAL, RESTRAINED              1
# ASSEMBLY, GENERAL                      1
# CHARITABLE  PHILANTHROPIC              1
# Name: U_code, Length: 47, dtype: int64
# MULTI-FAMILY DWELLING             785
# BUSINESS BUILDING                 568
# COMMERCIAL MISCELLANEOUS STRUC    294
# TOWNHOUSE                         178
# MERCANTILE BUILDING               170
# RESTAURANT                        143
# EDUCATIONAL BUILDING              130
# MULTIFAMILY DWELLING LOW RISE     106
# ASSEMBLY BUILDING                  75
# RETAINING WALL                     68
#                                  ...
# ASSEMBLY, GENERAL                   2
# INSTITUTIONAL BUILDING              2
# SHED                                2
# INSTITUTIONAL, RESTRAINED           1
# RESIDENTIAL, HOTELS                 1
# BOARDING HOUSE                      1
# INSTITUTIONAL, DAY CARE FAC.        1
# SINGLE FAMILY DWELLING              1
# INSTITUTIONAL, INCAPACITATED        1
# FACTORY                             1
# Name: U_code, Length: 45, dtype: int64
# MULTI-FAMILY DWELLING             916
# TOWNHOUSE                         334
# MULTIFAMILY DWELLING LOW RISE     155
# BUSINESS BUILDING                 121
# COMMERCIAL MISCELLANEOUS STRUC    112
# RETAINING WALL                     43
# EDUCATIONAL BUILDING               38
# MERCANTILE BUILDING                36
# ASSEMBLY BUILDING                  33
# MISCELLANEOUS STRUCTURE            32
#                                  ...
# BANK                                2
# BUSINESS                            1
# MULTI-FAMILY SENIOR CITIZEN BL      1
# FENCE                               1
# HOSPITAL                            1
# FACTORY AND INDUST, LOW HAZ         1
# MULTIFAMILY DWELLING HIGH RISE      1
# FACTORY AND INDUST, MOD HAZ         1
# DAY CARE                            1
# EDUCATIONAL                         1
# Name: U_code, Length: 29, dtype: int64

# %%
D2S1 = D6.loc[D2.NewCity == 'Silver Spring' ]
D2B1 = D6.loc[D2.NewCity == 'Bethesda' ]
D2R1 = D6.loc[D2.NewCity == 'Rockville' ]
D2G1 = D6.loc[D2.NewCity == 'Germantown']
D2C1 = D6.loc[D2.NewCity == 'Clarksburg' ]

# %%
display(D2S1['P_num'].value_counts().sum())
display(D2B1['P_num'].value_counts().sum())
display(D2R1['P_num'].value_counts().sum())
display(D2G1['P_num'].value_counts().sum())
display(D2C1['P_num'].value_counts().sum())
# Out:
# 4064
# 2844
# 2223
# 1246
# 250

# %%
display(D2S1['U_code'].value_counts())
display(D2B1['U_code'].value_counts())
display(D2R1['U_code'].value_counts())
display(D2G1['U_code'].value_counts())
display(D2C1['U_code'].value_counts())
# Out:
# BUSINESS BUILDING                 1200
# MULTI-FAMILY DWELLING              808
# MERCANTILE BUILDING                504
# RESTAURANT                         401
# COMMERCIAL MISCELLANEOUS STRUC     277
# EDUCATIONAL BUILDING               163
# ASSEMBLY BUILDING                  135
# PLACE OF WORSHIP                    70
# HOSPITAL                            60
# MULTIFAMILY DWELLING LOW RISE       51
#                                   ...
# EDUCATIONAL                          2
# STORAGE, MODERATE HAZARD             2
# RETAINING WALL                       2
# SWIMMING POOL & FENCE                1
# TRAILER                              1
# FACTORY AND INDUST, MOD HAZ          1
# DAY CARE                             1
# POOL - ABOVE GROUND                  1
# FACTORY AND INDUST, LOW HAZ          1
# ASSEMBLY, NIGHTCLUBS                 1
# Name: U_code, Length: 43, dtype: int64
# BUSINESS BUILDING                 1289
# MERCANTILE BUILDING                373
# RESTAURANT                         283
# MULTI-FAMILY DWELLING              165
# ASSEMBLY BUILDING                  124
# COMMERCIAL MISCELLANEOUS STRUC     121
# EDUCATIONAL BUILDING               104
# HOSPITAL                            73
# HOTEL                               44
# BANK                                43
#                                   ...
# ASSEMBLY, GENERAL                    2
# THEATER                              2
# STORAGE, LOW HAZARD                  2
# OWNERSHIP UNIT                       2
# UTILITY, MISCELLANEOUS               2
# SWIMMING POOL & FENCE                1
# BOARDING HOUSE                       1
# INSTITUTIONAL, SUPV ENVIRONMNT       1
# INSTITUTIONAL, INCAPACITATED         1
# TRAILER                              1
# Name: U_code, Length: 36, dtype: int64
# BUSINESS BUILDING                 1157
# MERCANTILE BUILDING                208
# RESTAURANT                         127
# MULTI-FAMILY DWELLING              105
# BIOSCIENCE                         100
# ASSEMBLY BUILDING                   85
# COMMERCIAL MISCELLANEOUS STRUC      80
# HOSPITAL                            69
# STORAGE BUILDING                    61
# EDUCATIONAL BUILDING                59
#                                   ...
# STORAGE, LOW HAZARD                  2
# INSTITUTIONAL, NURSING HOMES         1
# ASSEMBLY, RESTAURANTS                1
# CHARITABLE  PHILANTHROPIC            1
# TRAILER                              1
# PUBLIC UTILITY                       1
# INSTITUTIONAL, RESTRAINED            1
# UTILITY, MISCELLANEOUS               1
# BOARDING HOUSE                       1
# FENCE                                1
# Name: U_code, Length: 42, dtype: int64
# BUSINESS BUILDING                 486
# MULTI-FAMILY DWELLING             232
# MERCANTILE BUILDING               130
# RESTAURANT                        109
# COMMERCIAL MISCELLANEOUS STRUC     58
# EDUCATIONAL BUILDING               52
# ASSEMBLY BUILDING                  41
# MULTIFAMILY DWELLING LOW RISE      25
# BIOSCIENCE                         16
# BANK                               14
#                                  ...
# INSTITUTIONAL BUILDING              1
# INSTITUTIONAL, INCAPACITATED        1
# MULTI-FAMILY SENIOR CITIZEN BL      1
# UTILITY, MISCELLANEOUS              1
# SINGLE FAMILY DWELLING              1
# SWIMMING POOL                       1
# TRAILER                             1
# INSTITUTIONAL, DAY CARE FAC.        1
# MULTIFAMILY DWELLING HIGH RISE      1
# RESIDENTIAL, HOTELS                 1
# Name: U_code, Length: 35, dtype: int64
# BUSINESS BUILDING                 90
# TOWNHOUSE                         55
# ASSEMBLY BUILDING                 17
# MULTI-FAMILY DWELLING             16
# MERCANTILE BUILDING               15
# RESTAURANT                        13
# COMMERCIAL MISCELLANEOUS STRUC    13
# STORAGE BUILDING                  11
# EDUCATIONAL BUILDING               6
# MISCELLANEOUS STRUCTURE            3
# BANK                               2
# PLACE OF WORSHIP                   2
# DAY CARE                           1
# SWIMMING POOL                      1
# RETAINING WALL                     1
# FACTORY AND INDUST, MOD HAZ        1
# INDUSTRIAL BUILDING                1
# FACTORY AND INDUST, LOW HAZ        1
# BUSINESS                           1
# Name: U_code, dtype: int64

# %%
# years where permits were open 
OD = D3.loc[D3.Status == 'Open' ]
display(OD.year.value_counts())
display(OD.W_type.value_counts(normalize=True))
display(OD.U_code.value_counts(normalize=True))
# Out:
# 2019    573
# 2018    133
# 2015    114
# 2017     84
# 2007     73
# 2014     65
# 2016     56
# 2013     51
# 2012     49
# 2008     49
# 2011     42
# 2003     32
# 2005     29
# 2009     29
# 2006     28
# 2010     27
# 2001     14
# 2004     12
# 2002      3
# 2000      1
# Name: year, dtype: int64
# ALTER                         0.437842
# CONSTRUCT                     0.296448
# ADD                           0.099727
# RESTORE AND / OR REPAIR       0.088798
# COMMERCIAL CHANGE OF USE      0.032104
# INSTALL                       0.025956
# BUILD FOUNDATION              0.008197
# CONSTRUCT SHEETING/SHORING    0.004781
# FINAL ONLY AP                 0.003415
# DEMOLISH                      0.002049
# REPLACE                       0.000683
# Name: W_type, dtype: float64
# BUSINESS BUILDING                 0.230874
# COMMERCIAL MISCELLANEOUS STRUC    0.158470
# MERCANTILE BUILDING               0.062842
# RESTAURANT                        0.062158
# MULTIFAMILY DWELLING LOW RISE     0.057377
# MULTI-FAMILY DWELLING             0.056011
# ASSEMBLY BUILDING                 0.049863
# EDUCATIONAL BUILDING              0.049180
# TOWNHOUSE                         0.032104
# WIRELESS EQUIPMENT                0.029372
#                                     ...
# GARAGE                            0.001366
# RESIDENTIAL, HOTELS               0.001366
# STORAGE, LOW HAZARD               0.001366
# ASSEMBLY, CHURCHES                0.000683
# ASSEMBLY, RESTAURANTS             0.000683
# MERCANTILE                        0.000683
# MULTI-FAMILY SENIOR CITIZEN BL    0.000683
# INDUSTRIAL BUILDING               0.000683
# EDUCATIONAL                       0.000683
# STORAGE, MODERATE HAZARD          0.000683
# Name: U_code, Length: 41, dtype: float64

# %%
D2['Status'].value_counts(normalize=True)
# Out:
# Finaled      0.543444
# Issued       0.376760
# Open         0.052980
# Stop Work    0.026816
# Name: Status, dtype: float64

# %%
OS = D3.loc[D3.Status == 'Stop Work' ]
display(OS.W_type.value_counts(normalize=True))
display(OS.U_code.value_counts(normalize=True))
display(OS.year.value_counts(normalize=True))
# Out:
# CONSTRUCT                   0.545209
# ADD                         0.272605
# ALTER                       0.159244
# RESTORE AND / OR REPAIR     0.010796
# INSTALL                     0.005398
# COMMERCIAL CHANGE OF USE    0.004049
# BUILD FOUNDATION            0.002699
# Name: W_type, dtype: float64
# COMMERCIAL MISCELLANEOUS STRUC    0.252362
# EDUCATIONAL BUILDING              0.238866
# BUSINESS BUILDING                 0.130904
# RETAINING WALL                    0.068826
# TRAILER                           0.045884
# STORAGE BUILDING                  0.031039
# MULTI-FAMILY DWELLING             0.029690
# MISCELLANEOUS STRUCTURE           0.028340
# MERCANTILE BUILDING               0.025641
# PLACE OF WORSHIP                  0.024291
#                                     ...
# FENCE                             0.004049
# HOTEL                             0.002699
# INDUSTRIAL BUILDING               0.002699
# BIOSCIENCE                        0.002699
# MULTI-FAMILY SENIOR CITIZEN BL    0.001350
# BANK                              0.001350
# PUBLIC UTILITY                    0.001350
# ASSEMBLY, CHURCHES                0.001350
# INSTITUTIONAL BUILDING            0.001350
# MULTIFAMILY DWELLING LOW RISE     0.001350
# Name: U_code, Length: 30, dtype: float64
# 2013    0.182186
# 2014    0.147099
# 2012    0.136302
# 2018    0.112011
# 2016    0.112011
# 2017    0.097166
# 2015    0.078273
# 2001    0.031039
# 2000    0.022942
# 2019    0.017544
# 2011    0.014845
# 2002    0.013495
# 2003    0.012146
# 2004    0.008097
# 2009    0.004049
# 2005    0.004049
# 2010    0.004049
# 2008    0.001350
# 2006    0.001350
# Name: year, dtype: float64

# %% [markdown]
# # Conclusions
# In this project, I explored permit data for Montgomery County, Maryland. Based on my findings we can conclude the several things.
# 1. The amount and value of each permit issued in each city.
# 2. The fact that the county seems to be growing as more and more permits are being issued.
# 3. There is growing percentage of new multi-family dwellings vs. the amount of single family houses.
# 4. Mall and hospitals permits have the highest permit density.
# 5. Most permits are concentrated in the top five cities.
# 6. Construction and alterations have the longest wait time and make up the majority of permits.
# 7. The wait time of a permit is similar to what the county claims.
# 8. Most structures having commercial permits issued for them are Business Buildings and Multi-family Dwellings.
# 9. Work type and and Area, Use code and value are correlated.
# 10. Area and Value and Value are correlated
