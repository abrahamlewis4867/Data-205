# %%
import os
import pandas as pd
import numpy as np

# %%
cp = pd.read_csv('Commercial_Permits (1).csv')
cp
# Out:
#        Permit Number     Status Street Number Pre-direction  \
# 0             605247     Issued         11311           NaN
# 1             611513     Issued         11141           NaN
# 2             616559     Issued         18100           NaN
# 3             621796    Finaled         12180           NaN
# 4             684881       Open         16701           NaN
# 5             208677    Finaled         19850           NaN
# 6             208679    Finaled         12903           NaN
# 7             208689    Finaled         12907           NaN
# 8             208691    Finaled         12925           NaN
# 9             208782    Finaled         20001           NaN
# 10            208783    Finaled         20001           NaN
# 11            618202     Issued          5601           NaN
# 12            638560     Issued          3421           NaN
# 13            209085    Finaled          5335           NaN
# 14            751509     Issued         14800           NaN
# ...

# %%
cp.describe
# Out:
# <bound method NDFrame.describe of        Permit Number     Status Street Number Pre-direction  \
# 0             605247     Issued         11311           NaN
# 1             611513     Issued         11141           NaN
# 2             616559     Issued         18100           NaN
# 3             621796    Finaled         12180           NaN
# 4             684881       Open         16701           NaN
# 5             208677    Finaled         19850           NaN
# 6             208679    Finaled         12903           NaN
# 7             208689    Finaled         12907           NaN
# 8             208691    Finaled         12925           NaN
# 9             208782    Finaled         20001           NaN
# 10            208783    Finaled         20001           NaN
# 11            618202     Issued          5601           NaN
# 12            638560     Issued          3421           NaN
# 13            209085    Finaled          5335           NaN
# ...

# %%
cp.dtypes
# Out:
# Permit Number           int64
# Status                 object
# Street Number          object
# Pre-direction          object
# Street Name            object
# Street Suffix          object
# Post-direction         object
# City                   object
# State                  object
# ZIP code              float64
# Added Date             object
# Issue Date             object
# Final Date             object
# Building Area         float64
# Declared Valuation    float64
# Description            object
# Application Type       object
# Work Type              object
# Use Code               object
# Location               object
# dtype: object
